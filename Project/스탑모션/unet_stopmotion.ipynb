# %% [markdown]
# 라이브러리 , 마운트
# ================================

# %%
from google.colab import drive
drive.mount('/content/drive')

import tensorflow as tf
import keras
import keras.backend as K
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os,shutil,cv2,glob

import pickle
# Out:
# Mounted at /content/drive

# %% [markdown]
# 기본 데이터 정의
# ============

# %%
SEED = 909

#배치사이즈
BATCH_SIZE = 1

#에폭의 수
NUM_OF_EPOCHS = 50

#UNet 깊이
UNet_level = 5

#Train,Valid 비율
validation_ratio=0.2

#초기 피쳐의 수
initial_features = 32

#input channel
input_channels = 3

#백그라운드 포함 클래스 아웃풋 개수 (grayscale의 경우 1)
num_class=1

IMAGE_HEIGHT = 960
IMAGE_WIDTH = 640
IMG_SIZE = (IMAGE_HEIGHT, IMAGE_WIDTH)

data_dir = '/content/drive/MyDrive/newstudy/mulimedia'
data_dir_train = os.path.join(data_dir, '')
# 저장해야할 장소: "data/slices/training/img/img"
data_dir_train_image = os.path.join(data_dir_train, 'img')
# 저장해야할 장소: "data/slices/training/mask/img"
data_dir_train_mask = os.path.join(data_dir_train, 'mask')

# %%
#클래스 설정 

#클래스 색삭 자동지정 함수
def autoclass(num): 
  class_list=[[0,0,0]] #BG 컬러를 0으로 지정
  for i in range(num-1):
    class_list.append(list(np.random.choice(range(256), size=3)))
  return sorted(class_list)

#클래스별 색상
if num_class > 1:

  c =[[0,0,0], [255,255,255]]
  c = autoclass(num_class) #자동지정 list로 [R,G,B]형식으로 만들면 됨
      

  #정보 출력
  print(f'표현가능 클래스 개수 : {len(c)}')
  print(f'클래스별 색상표 : {c}')
  for i in range(1,len(c)):
    if c[i-1] == c[i]:
      print("중복 색상이 존재합니다.",i-1,i)

# %% [markdown]
# 출력함수
# ==============================

# %%
def applycolor(img,color):
  #클래스 이미지에 색 적용
  h,w,c = img.shape

  for i in range(h):
    for j in range(w):
      for k in range(c):
        img[i,j,k] = color[img[i,j,k]][k]

  return img

num=0

def display(display_list, opt=0):
  global num
  plt.figure(figsize=(15,15))
    
  title = [['Input Image', 'True Mask','Mixed Mask'],['Input Image', 'True Mask', 'Predicted Mask','Mixed Mask'],['Predicted Mask', 'Predicted Mask','Mixed Mask']]
    
  for i in range(len(display_list)):
    plt.subplot(1, len(display_list), i+1)
    plt.title(title[opt][i])
    plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
  if os.path.exists('/content/drive/MyDrive/newstudy/mulimedia/graphs/') == False:
    os.mkdir('/content/drive/MyDrive/newstudy/mulimedia/graphs/')
  plt.savefig(f'/content/drive/MyDrive/newstudy/mulimedia/graphs/Graph{num}.png')
  num+=1
  plt.show()
  

def predict_img(img,get_last=False): 

  prediction = model.predict(np.expand_dims(img,axis=0))

  if type(model.output) == list:
    num_of_output = len(model.output)
    x = prediction[num_of_output-1] if get_last else sum(prediction) / num_of_output
  else:
    x = prediction

  if num_class ==1:
    x= x[0]
    x[x>=0.5] = 1
    x[x<0.5] = 0
    x *= 255
  else:
    x = np.argmax(x[0], axis=-1) #해당픽셀의 채널 중에서 가장 큰 인덱스 값 가져옴 h,w
    x = np.expand_dims(x, axis=-1) #각 픽셀을단일로묶음 h,w,1
    x = x.astype(np.int32) #각 픽셀의 값을 int로 h,w,1
    x = np.concatenate([x, x, x], axis=2) #각픽셀 값을 3번 이어서 3채널로 만들어줌
    x = applycolor(x,c)

  return x


def display_dataset(ds,predict=False,num=1):
  i=0
  for x, y in ds:
    if i== num:
      break;
    display_list = []

    dx = x[0] * 255
    dx = dx.numpy()

    if num_class ==1:
      dy = y[0] * 255
      if (input_channels == 3):
        dy = np.concatenate([dy, dy, dy], axis=2)
      else :
        dy = dy.numpy()
    else :
      dy = np.argmax(y[0], axis=-1)
      dy = np.expand_dims(dy, axis=-1) #각 픽셀을단일로묶음 h,w,1
      dy = dy.astype(np.int32) #각 픽셀의 값을 int로 h,w,1
      dy = np.concatenate([dy, dy, dy], axis=2)
      dy = applycolor(dy,c)

    display_list.append(dx)
    display_list.append(dy)

    if predict:
      if input_channels == 1:
        p = predict_img(np.expand_dims(x[0], axis=0))
        p = np.concatenate([p, p, p], axis=2)
      else :
        p = predict_img(x[0])
        p = np.concatenate([p, p, p], axis=2)
      display_list.append(p)

    if num_class == 1:
      display_list.append(cv2.addWeighted(dx, 1, display_list[predict+1], 0.5,0))
    else:
      display_list.append(cv2.addWeighted(dx.astype(np.int32), 1, display_list[predict+1], 0.5,0))
    
    display(display_list,predict)
    i+=1

def display_test(files,num=1):
  for i in range(num):
      display_list = []
      x = read_image("/content/drive/MyDrive/newstudy/mulimedia/frame/"+str(i+1)+".png") 
      dx = x*255
      
      if input_channels == 1:
        p = predict_img(np.expand_dims(x, axis=0))
      else:
        p = predict_img(x)
        if num_class == 1:
          p = np.concatenate([p, p, p], axis=2)
      display_list.append(dx)
      display_list.append(p)

      print(dx.shape,p.shape)
      if num_class == 1:
        display_list.append(cv2.addWeighted(dx, 1, p, 0.5,0))
      else:
        display_list.append(cv2.addWeighted(display_list[0].astype(np.int32), 1, p, 0.5,0))
      display(display_list,2)

#model 학습 정보 표시,저장
def display_history(history, dir, num,save_pic=True,save_csv=True,save_best_infor=True):
  t = ['Accuracy','Loss']
  k = ['accuracy','loss']
  p = ['lower','upper']


  if type(model.output) != list : num_of_output = 1
  else: num_of_output = len(model.output)

  plt.figure(figsize=(24,3*num_of_output))

  for i in range(num_of_output):

    if type(model.output) != list : name = ''
    else: name = model.output_names[i]+'_'

    for j in range(4):
      plt.subplot(num_of_output,4,i*4+j+1)
      if j%2==0 :
        plt.plot(history[f'{name}{k[j//2]}'], 'g-', label= k[j//2])
        if i==0:
          plt.title(t[j//2])
      else :
        plt.plot(history[f'val_{name}{k[j//2]}'], 'g-', label= 'val_'+k[j//2])
        if i==0:
          plt.title('Val_'+t[j//2])
      if j==0:
        plt.ylabel(f'Output[{i}]')
      elif i== num_of_output-1 :
        plt.xlabel('Epoch')
      plt.legend(loc= p[j//2]+' right')
      plt.grid(True, axis='both',alpha=0.5)

  if (save_pic) : 
    plt.savefig(f'{dir}/Graph{num}.png')

  if (save_csv):
    hist_df = pd.DataFrame(history) 
    with open(f'{dir}/History{num}.csv', mode='w') as f:
      hist_df.to_csv(f)

  if (save_best_infor):
    idx = np.argmin(history['val_loss'])
    result = [['Epoch'],[idx+1]]
    start_idx = 1-(type(history) == dict)
    for i in range(start_idx,len(history.keys())):
      key = list(history.keys())[i]
      result[0].append(key)
      result[1].append(history[key][idx])
    hist_df = pd.DataFrame(result) 
    with open(f'{dir}/Best{num}.Infor.csv', mode='w') as f:
      hist_df.to_csv(f)
      
  plt.show()

# %% [markdown]
# 데이터 전처리
# ====================

# %%
#https://www.youtube.com/watch?v=C5CbsTDwQM0
def read_image(path):
  if input_channels == 1:
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (IMAGE_WIDTH,IMAGE_HEIGHT))
    x = x / 255.0
    x = np.expand_dims(x, axis=-1) #grayscale의 경우 추가 아니면 그냥 삭제
  else:
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    x = cv2.resize(x, (IMAGE_WIDTH,IMAGE_HEIGHT))
    x = x / 255.0
  x = x.astype(np.float32)
  return x

def read_mask(path):
  x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
  x[x==41] =0
  x[x==19] =0
  x[x==47] =0
  x[x==17] =0
  x[x>0] =1
  x = cv2.resize(x, (IMAGE_WIDTH,IMAGE_HEIGHT))

  if num_class == 1:
    #x = x / 255.0 #이미지가 1 2 3으로 구성되면 필요 x
    x = np.expand_dims(x, axis=-1) #onehotencode를 나중에 하게 된다면 필요없음
    x = x.astype(np.float32)
  else :
    x = x.astype(np.int32)
  return x

def tf_dataset(x, y, batch_size=1):
  dataset = tf.data.Dataset.from_tensor_slices((x, y))
  dataset = dataset.shuffle(buffer_size=1000)
  dataset = dataset.map(preprocess,num_parallel_calls=tf.data.experimental.AUTOTUNE)
  dataset = dataset.batch(batch_size)
  dataset = dataset.repeat()
  dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
  return dataset

def preprocess(x, y):
  def f(x, y):
    x = x.decode()
    y = y.decode()

    x = read_image(x)
    y = read_mask(y)

    return x, y

  if (num_class==1):
    image, mask = tf.numpy_function(f, [x, y], [tf.float32, tf.float32])
  else:
    image, mask = tf.numpy_function(f, [x, y], [tf.float32, tf.int32])
    mask = tf.one_hot(mask, num_class, dtype=tf.int32)
  image.set_shape([IMAGE_HEIGHT, IMAGE_WIDTH, input_channels])
  mask.set_shape([IMAGE_HEIGHT, IMAGE_WIDTH, num_class])

  return image, mask

train_x = sorted(glob.glob(os.path.join(data_dir_train_image, '*.png')))
train_y = sorted(glob.glob(os.path.join(data_dir_train_mask, '*.png')))

train_x, valid_x = train_test_split(train_x, test_size=validation_ratio, random_state=SEED)
train_y, valid_y = train_test_split(train_y, test_size=validation_ratio, random_state=SEED)

  
print(f"Dataset: Train: {len(train_x)} - Valid: {len(valid_x)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=BATCH_SIZE)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=BATCH_SIZE)
# Out:
# Dataset: Train: 96 - Valid: 24

# %%
NUM_TRAIN = len(train_x)

NUM_VALID = len(valid_x)

EPOCH_STEP_TRAIN = NUM_TRAIN // BATCH_SIZE
EPOCH_STEP_VALID = NUM_VALID // BATCH_SIZE

# %%
display_dataset(train_dataset,False,2)

# %% [markdown]
# 사용자 정의 손실함수
# ================================

# %%
def DiceBCELoss(y_true, y_pred,smooth=1e-5):    
    
    y_true_f= K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    BCE =  tf.keras.losses.binary_crossentropy(y_true_f, y_pred_f)
    intersection = K.sum(y_true_f * y_pred_f, axis=-1)
    dice_loss = 1 - (2 * intersection + smooth) / (K.sum(y_true_f,-1) + K.sum(y_pred_f,-1) + smooth)
    Dice_BCE = BCE + dice_loss
    
    return Dice_BCE
    
def IoULoss(y_true, y_pred, smooth=1e-6):

    y_pret_f = K.flatten(y_pred)
    y_true_f = K.flatten(y_true)
    
    intersection = K.sum(y_true_f* y_pret_f)
    total = K.sum(y_true_f) + K.sum(y_pret_f)
    union = total - intersection
    
    IoU = (intersection + smooth) / (union + smooth)
    return 1 - IoU

# 0.5 4/3

# 0.8 2.0
def FocalLoss(y_true, y_pred, alpha=1.0, gamma=2.0):    
    
    y_pret_f = K.flatten(y_pred)
    y_true_f = K.flatten(y_true)
    
    BCE = K.binary_crossentropy(y_true_f, y_pret_f)
    BCE_EXP = K.exp(-BCE)
    focal_loss = K.mean(alpha * K.pow((1-BCE_EXP), gamma) * BCE)
    
    return focal_loss

def Focal_IoU(y_true, y_pred):
  return FocalLoss(y_true,y_pred) + IoULoss(y_true, y_pred)

custom_loss = {'DiceBCELoss': DiceBCELoss,'Focal_IoU':Focal_IoU}

# %% [markdown]
# U-Net
# ====================

# %%
def conv(input,features,kernel_size=3,strides = 1,padding='same',is_relu=True,is_bn=True):
  x = keras.layers.Conv2D(features,kernel_size,strides,padding,kernel_initializer='he_normal')(input)
  if is_bn:
    x = keras.layers.BatchNormalization()(x)

  if is_relu:
    x = keras.activations.relu(x)

  return x

def unet(n_levels, initial_features=initial_features, n_blocks=2, kernel_size=3, pooling_size=2, in_channels=input_channels, out_channels=num_class):
  inputs = keras.layers.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, in_channels))
  x = inputs
  
  #인코더부분
  skips = []
  for level in range(n_levels):
    if level != 0 :
      x = keras.layers.MaxPool2D(pooling_size)(x)
    for _ in range(n_blocks):
      x = conv(x,initial_features * 2 ** level,3,1,'same')
    skips.append(x)

  # 디코더 부분
  for level in reversed(range(n_levels-1)):
    x = keras.layers.UpSampling2D(pooling_size, interpolation='bilinear')(x) 
    x = conv(x,initial_features * 2 ** level,2,1,'same')

    x = keras.layers.Concatenate()([x, skips[level]])
    for _ in range(n_blocks):
      x = conv(x,initial_features * 2 ** level,3,1,'same')
          
  # 결과
  x = keras.layers.Conv2D(out_channels, kernel_size=1, padding='same')(x)

  if out_channels == 1:
    x = keras.activations.sigmoid(x)
  else:
    x = keras.activations.softmax(x)
  
  return keras.Model(inputs=[inputs], outputs=x, name=f'UNET-L{n_levels}-F{initial_features}')

model = unet(UNet_level)

# %%
def conv(input,features,kernel_size=3,strides = 1,padding='same',is_relu=True,is_bn=False):
  x= keras.layers.Conv2D(features,kernel_size,strides,padding,kernel_initializer='he_normal')(input)
  if is_bn:
    x = keras.layers.BatchNormalization()(x)
  if is_relu:
    x = keras.activations.relu(x)
  return x

def unet2(n_levels,DSV=True, initial_features=initial_features, n_blocks=2, kernel_size=3, pooling_size=2, in_channels=input_channels, out_channels=num_class):
  inputs = keras.layers.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, in_channels))
  x = inputs

  #인코더부분
  skips = []

  for _ in range(n_levels):
    skips.append(list())

  for level in range(n_levels):
    if level != 0 :
      x = keras.layers.MaxPool2D(pooling_size)(x)
    for _ in range(n_blocks):
      x = conv(x,initial_features * 2 ** level,3,1,'same')
    skips[level].append(x)


  #스킵 생성 부분
  for i in range(1,n_levels):
    for level in range(n_levels-i):
      list_concat = []

      for row in range(i):
        list_concat.append(skips[level][row])
      
      x = skips[level+1][i-1]
      x = keras.layers.UpSampling2D(pooling_size, interpolation='bilinear')(x) 
      list_concat.append(x)

      x = keras.layers.Concatenate()(list_concat)
      for _ in range(n_blocks):
        x = conv(x,initial_features * 2 ** level,3,1,'same')
      skips[level].append(x)
          
  # 출력부분
  result = []
  if DSV:
    for i in range(1,n_levels):
      result.append(keras.layers.Conv2D(out_channels, kernel_size=1, padding='same')(skips[0][i]))
  else:
    result.append(keras.layers.Conv2D(out_channels, kernel_size=1, padding='same')(skips[0][-1]))
  
  for i in range(len(result)):
    if out_channels == 1:
      result[i] = keras.activations.sigmoid(result[i])
    else:
      result[i] = keras.activations.softmax(result[i])
  
  #모델 이름 설정
  output_name=f'UNET2-L{n_levels}-F{initial_features}'
  if DSV:
    output_name+='-DSV'

  return keras.Model(inputs=[inputs], outputs=result, name=output_name)

model = unet2(UNet_level,True)

# %% [markdown]
# U-Net3+
# ==============

# %%
def conv(input,features,kernel_size=3,strides = 1,padding='same',is_relu=True,is_bn=False):
  x= keras.layers.Conv2D(features,kernel_size,strides,padding,kernel_initializer='he_normal')(input)
  if is_bn:
    x = keras.layers.BatchNormalization()(x)
  if is_relu:
    x = keras.activations.relu(x)
  return x

def dotProduct(seg, cls):
  B, H, W, N = K.shape(seg)
  seg = tf.reshape(seg, [B, H*W, N])
  final = tf.einsum("ijk,ik->ijk", seg, cls)
  final = tf.reshape(final, [B, H, W, N])
  return final

def unet3(n_levels,DSV=True,CGM=True, initial_features=initial_features, n_blocks=2, kernel_size=3, pooling_size=2, in_channels=input_channels, out_channels=num_class):
  inputs = keras.layers.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, in_channels))
  x = inputs
  
  #인코더부분
  skips = {}
  output = []
  for level in range(n_levels):
    if level != 0 :
      x = keras.layers.MaxPool2D(pooling_size)(x)
    for _ in range(n_blocks):
      x = conv(x,initial_features * 2 ** level,3,1,'same')
    skips[level] = x 

    if level == n_levels-1:
      output.append(x)

  # CGM
  if CGM:
    cgm = keras.layers.Dropout(rate=0.5)(output[0])
    cgm = keras.layers.Conv2D(2, kernel_size=(1, 1), padding="same")(cgm)
    cgm = keras.layers.GlobalMaxPooling2D()(cgm)
    cgm = keras.activations.sigmoid(cgm)

    cgm = tf.argmax(cgm,axis=-1)
    cgm = cgm[..., tf.newaxis]
    cgm = tf.cast(cgm, dtype=tf.float32)

  #디코더 부분
  for level in reversed(range(n_levels-1)): 
    list_concat = []

    #위에 레벨+ 동일레벨
    for i in range(level+1):
      x = skips[i]
      x = keras.layers.MaxPool2D(pooling_size**(level-i))(x)
      x = conv(x,initial_features,3,1,'same',is_relu = False)
      list_concat.append(x)

    #아래 레벨
    for i in range(level+1,n_levels):
      x = output[n_levels-i-1]
      x = keras.layers.UpSampling2D(pooling_size**(i-level), interpolation='bilinear')(x)
      x = conv(x,initial_features,3,1,'same',is_relu = False)
      list_concat.append(x)

    #concat 부분
    x = keras.layers.concatenate(list_concat)
    for i in range(1): #논문에서는 1회만 진행
      x = conv(x,initial_features * n_levels,3,1,'same',is_bn = True)
    output.append(x)

  # 출력부분
  result = []
  if DSV:
    for i in range(n_levels):
      output[i] = keras.layers.Conv2D(out_channels, kernel_size=3, padding='same',kernel_initializer='he_normal')(output[i])
      output[i] = keras.layers.UpSampling2D(2**(n_levels-i-1), interpolation='bilinear')(output[i])
      if CGM:
        output[i] = keras.layers.multiply([output[i],cgm])
      result.append(output[i])
  else:
    result.append(keras.layers.Conv2D(out_channels, kernel_size=3, padding='same',kernel_initializer='he_normal')(output[n_levels-1]))

  for i in range(len(result)):
    if out_channels == 1:
      result[i] = keras.activations.sigmoid(result[i])
    else:
      result[i] = keras.activations.softmax(result[i])


  #이름 설정
  output_name=f'UNET3-L{n_levels}-F{initial_features}'
  if DSV:
    output_name+='-DSV'

  if CGM:
    output_name+='-CGM'

  return keras.Model(inputs=[inputs], outputs=result, name=output_name)


model = unet3(UNet_level,True,False)

# %%
def conv(input,features,kernel_size=3,strides = 1,padding='same',is_relu=True,is_bn=False):
  x= keras.layers.Conv2D(features,kernel_size,strides,padding,kernel_initializer='he_normal')(input)
  if is_bn:
    x = keras.layers.BatchNormalization()(x)
  if is_relu:
    x = keras.activations.relu(x)
  return x

def UNETsharp(n_levels,DSV=True, initial_features=initial_features, n_blocks=2, kernel_size=3, pooling_size=2, in_channels=input_channels, out_channels=num_class):
  inputs = keras.layers.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, in_channels))
  x = inputs

  skips = []
  for _ in range(n_levels):
    skips.append(list())

  #인코더부분
  for level in range(n_levels):
    if level != 0 :
      x = keras.layers.MaxPool2D(pooling_size)(x)
    for _ in range(n_blocks):
      x = conv(x,initial_features * 2 ** level,3,1,'same')
    skips[level].append(x)

  #스킵 생성 부분
  for i in range(1,n_levels):
    for level in range(n_levels-i):
      list_concat = []

      #같은레벨
      for col in range(i):
        list_concat.append(skips[level][col])

      #아래 레벨
      for j in range(i):
        x = keras.layers.UpSampling2D(pooling_size**(j+1), interpolation='bilinear')(skips[level+j+1][i-j-1])
        if (j>0):
          x = conv(x,initial_features*2**level,3,1,'same')
        list_concat.append(x)

      x = keras.layers.concatenate(list_concat)
      for _ in range(n_blocks):
        x = conv(x,initial_features *2**level,3,1,'same')
      skips[level].append(x)
          
  # 출력부분
  result = []
  if DSV:
    #같은 레벨
    for i in range(1,n_levels):
      result.append(keras.layers.Conv2D(out_channels, kernel_size=1,  padding='same',kernel_initializer='he_normal')(skips[0][i]))

    for i in range(1,n_levels):
      x = keras.layers.Conv2D(out_channels, kernel_size=3, padding='same',kernel_initializer='he_normal')(skips[i][-1])
      x = keras.layers.UpSampling2D(pooling_size**(i), interpolation='bilinear')(x)
      result.append(x)
  else:
    result.append(keras.layers.Conv2D(out_channels, kernel_size=1, padding='same',kernel_initializer='he_normal')(skips[0][-1]))

  for i in range(len(result)):
    if out_channels == 1:
      result[i] = keras.activations.sigmoid(result[i])
    else:
      result[i] = keras.activations.softmax(result[i])

  output_name=f'UNETsharp-L{n_levels}-F{initial_features}'

  if DSV:
    output_name+='-DSV'

  return keras.Model(inputs=[inputs], outputs=result, name=output_name)

model = UNETsharp(UNet_level,True)

# %%
def conv(input,features,kernel_size=3,strides = 1,padding='same',is_relu=True,is_bn=False):
  x= keras.layers.Conv2D(features,kernel_size,strides,padding,kernel_initializer='he_normal')(input)
  if is_bn:
    x = keras.layers.BatchNormalization()(x)
  if is_relu:
    x = keras.activations.relu(x)
  return x

def layerUNET(n_levels,DSV=True ,initial_features=initial_features, n_blocks=2, kernel_size=3, pooling_size=2, in_channels=input_channels, out_channels=num_class):
    inputs = keras.layers.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, in_channels))
    x = inputs

    skips = []
    for _ in range(n_levels):
      skips.append(list())

    #인코더부분
    for level in range(n_levels):
      if level != 0 :
        x = keras.layers.MaxPool2D(pooling_size)(x)
      for _ in range(n_blocks):
        x = conv(x,initial_features * 2 ** level,3,1,'same')
      skips[level].append(x)

    #스킵 생성 부분
    for i in range(1,n_levels):
      for level in range(n_levels-i):
        list_concat = []

        #같은 레벨
        x = conv(skips[level][0],initial_features,3,1,'same')
        list_concat.append(x)

        #위에레벨
        for row in range(level):
          x = keras.layers.MaxPool2D(pooling_size**(level-row))(skips[row][0])
          x = conv(x,initial_features,3,1,'same')
          list_concat.append(x)
        
        #아래 레벨
        for j in range(i):
          x = keras.layers.UpSampling2D(pooling_size**(j+1), interpolation='bilinear')(skips[level+j+1][i-j-1])
          x = conv(x,initial_features,3,1,'same')
          list_concat.append(x)
        
        if (i>1):
          tmp = []
          for j in range(1,i):
            tmp.append(skips[level][j])
          if (len(tmp)>1):
            x = keras.layers.concatenate(tmp)
          else :
            x = tmp[0]
          x = conv(x,initial_features,3,1,'same',is_relu =True)
          list_concat.append(x)

        #Concatenate 부분
        x = keras.layers.concatenate(list_concat)
        for _ in range(1): #1회가 평균적으로 성능은 더 좋음
          x = conv(x,initial_features * len(list_concat),3,1,'same',is_bn= True)
        skips[level].append(x)
    
    # 출력부분
    result = []
    
    if DSV:
      for i in range(1,n_levels):
        x = keras.layers.Conv2D(out_channels, kernel_size=1, padding='same',kernel_initializer='he_normal')(skips[0][i])
        result.append(x)

      for i in range(1,n_levels):
        x = keras.layers.Conv2D(out_channels, kernel_size=3, padding='same',kernel_initializer='he_normal')(skips[i][-1])
        x = keras.layers.UpSampling2D(pooling_size**(i), interpolation='bilinear')(x)
        result.append(x)
    else:
      result.append(keras.layers.Conv2D(out_channels, kernel_size=1, padding='same',kernel_initializer='he_normal')(skips[0][-1]))
    
    for i in range(len(result)):
      if out_channels == 1:
        result[i] = keras.activations.sigmoid(result[i])
      else:
        result[i] = keras.activations.softmax(result[i])

    output_name=f'LayerUNET-L{n_levels}-F{initial_features}'

    if DSV:
      output_name+=f'-DSV'

    return keras.Model(inputs=[inputs], outputs=result, name=output_name)

model = layerUNET(UNet_level,True)

# %%
def conv(input,features,kernel_size=3,strides = 1,padding='same',is_relu=True,is_bn=False):
  x= keras.layers.Conv2D(features,kernel_size,strides,padding,kernel_initializer='he_normal')(input)
  if is_bn:
    x = keras.layers.BatchNormalization()(x)
  if is_relu:
    x = keras.activations.relu(x)
  return x

def testedUNET(n_levels,DSV=True,CGM=True ,initial_features=initial_features, n_blocks=2, kernel_size=3, pooling_size=2, in_channels=input_channels, out_channels=num_class):
    inputs = keras.layers.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, in_channels))
    x = inputs

    skips = []
    for _ in range(n_levels):
      skips.append(list())

    #인코더부분
    for level in range(n_levels):
      if level != 0 :
        x = keras.layers.MaxPool2D(pooling_size)(x)
      for _ in range(n_blocks):
        x = conv(x,initial_features * 2 ** level,3,1,'same')
      skips[level].append(x)
      
    #스킵 생성 부분
    for i in range(1,n_levels):
      for level in reversed(range(n_levels-i)):
        list_concat = []

        #같은 레벨
        x = conv(skips[level][i-1],initial_features,3,1,'same')
        list_concat.append(x)

        #위에레벨
        for row in range(level):
          x = keras.layers.MaxPool2D(pooling_size**(level-row))(skips[row][i-1])
          x = conv(x,initial_features,3,1,'same')
          list_concat.append(x)
        
        #아래 레벨
        if (i+level == n_levels-1):
          for j in range(i):
            x = keras.layers.UpSampling2D(pooling_size**(j+1), interpolation='bilinear')(skips[level+j+1][i-j-1])
            x = conv(x,initial_features,3,1,'same')
            list_concat.append(x)
        else:
          x = keras.layers.UpSampling2D(pooling_size, interpolation='bilinear')(skips[level+1][i-1])
          x = conv(x,initial_features,3,1,'same')
          list_concat.append(x)
          for j in range(level+1,n_levels-i):
            x = keras.layers.UpSampling2D(pooling_size**(j-level), interpolation='bilinear')(skips[j][i])
            x = conv(x,initial_features,3,1,'same')
            list_concat.append(x)
        
        #Concatenate 부분
        x = keras.layers.concatenate(list_concat)
        for _ in range(1):
          x = conv(x,initial_features * len(list_concat),3,1,'same',is_bn=True)
        skips[level].append(x)
    
    # 출력부분
    result = []
    
    if DSV:

      for i in range(1,n_levels):
        x = keras.layers.Conv2D(out_channels, kernel_size=1,  padding='same',kernel_initializer='he_normal')(skips[0][i])
        result.append(x)

      for i in range(1,n_levels):
        x = keras.layers.Conv2D(out_channels, kernel_size=3, padding='same',kernel_initializer='he_normal')(skips[i][-1])
        x = keras.layers.UpSampling2D(pooling_size**(i), interpolation='bilinear')(x)
        result.append(x)
    else:
      result.append(keras.layers.Conv2D(out_channels, kernel_size=1, padding='same',kernel_initializer='he_normal')(skips[0][-1]))
    
    for i in range(len(result)):
      if out_channels == 1:
        result[i] = keras.activations.sigmoid(result[i])
      else:
        result[i] = keras.activations.softmax(result[i])

    output_name=f'testedUNET-L{n_levels}-F{initial_features}'

    if DSV:
      output_name+= f'-DSV'

    return keras.Model(inputs=[inputs], outputs=result, name=output_name)


model = testedUNET(UNet_level,True)

# %% [markdown]
# 모델 요약
# =====================

# %%
model.summary()
# Out:
# Model: "LayerUNET-L5-F32-DSV"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 960, 640, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 960, 640, 32  896         ['input_1[0][0]']
#                                 )
#
#  tf.nn.relu (TFOpLambda)        (None, 960, 640, 32  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 960, 640, 32  9248        ['tf.nn.relu[0][0]']
#                                 )
#
#  tf.nn.relu_1 (TFOpLambda)      (None, 960, 640, 32  0           ['conv2d_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 480, 320, 32  0           ['tf.nn.relu_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 480, 320, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  tf.nn.relu_2 (TFOpLambda)      (None, 480, 320, 64  0           ['conv2d_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 480, 320, 64  36928       ['tf.nn.relu_2[0][0]']
#                                 )
#
#  tf.nn.relu_3 (TFOpLambda)      (None, 480, 320, 64  0           ['conv2d_3[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 240, 160, 64  0          ['tf.nn.relu_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 240, 160, 12  73856       ['max_pooling2d_1[0][0]']
#                                 8)
#
#  tf.nn.relu_4 (TFOpLambda)      (None, 240, 160, 12  0           ['conv2d_4[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 240, 160, 12  147584      ['tf.nn.relu_4[0][0]']
#                                 8)
#
#  tf.nn.relu_5 (TFOpLambda)      (None, 240, 160, 12  0           ['conv2d_5[0][0]']
#                                 8)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 120, 80, 128  0          ['tf.nn.relu_5[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 120, 80, 256  295168      ['max_pooling2d_2[0][0]']
#                                 )
#
#  tf.nn.relu_6 (TFOpLambda)      (None, 120, 80, 256  0           ['conv2d_6[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 120, 80, 256  590080      ['tf.nn.relu_6[0][0]']
#                                 )
#
#  tf.nn.relu_7 (TFOpLambda)      (None, 120, 80, 256  0           ['conv2d_7[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 60, 40, 256)  0          ['tf.nn.relu_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 60, 40, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  tf.nn.relu_8 (TFOpLambda)      (None, 60, 40, 512)  0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 60, 40, 512)  2359808     ['tf.nn.relu_8[0][0]']
#
#  tf.nn.relu_9 (TFOpLambda)      (None, 60, 40, 512)  0           ['conv2d_9[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 480, 320, 32  0          ['tf.nn.relu_1[0][0]']
#                                 )
#
#  up_sampling2d_1 (UpSampling2D)  (None, 480, 320, 12  0          ['tf.nn.relu_5[0][0]']
#                                 8)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 240, 160, 32  0          ['tf.nn.relu_1[0][0]']
#                                 )
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 240, 160, 64  0          ['tf.nn.relu_3[0][0]']
#                                 )
#
#  up_sampling2d_2 (UpSampling2D)  (None, 240, 160, 25  0          ['tf.nn.relu_7[0][0]']
#                                 6)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 120, 80, 32)  0          ['tf.nn.relu_1[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 120, 80, 64)  0          ['tf.nn.relu_3[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 120, 80, 128  0          ['tf.nn.relu_5[0][0]']
#                                 )
#
#  up_sampling2d_3 (UpSampling2D)  (None, 120, 80, 512  0          ['tf.nn.relu_9[0][0]']
#                                 )
#
#  up_sampling2d (UpSampling2D)   (None, 960, 640, 64  0           ['tf.nn.relu_3[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 480, 320, 32  18464       ['tf.nn.relu_3[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 480, 320, 32  9248        ['max_pooling2d_4[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 480, 320, 32  36896       ['up_sampling2d_1[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 240, 160, 32  36896       ['tf.nn.relu_5[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 240, 160, 32  9248        ['max_pooling2d_5[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 240, 160, 32  18464       ['max_pooling2d_6[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 240, 160, 32  73760       ['up_sampling2d_2[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 120, 80, 32)  73760       ['tf.nn.relu_7[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 120, 80, 32)  9248        ['max_pooling2d_7[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 120, 80, 32)  18464       ['max_pooling2d_8[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 120, 80, 32)  36896       ['max_pooling2d_9[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 120, 80, 32)  147488      ['up_sampling2d_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 960, 640, 32  9248        ['tf.nn.relu_1[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 960, 640, 32  18464       ['up_sampling2d[0][0]']
#                                 )
#
#  tf.nn.relu_13 (TFOpLambda)     (None, 480, 320, 32  0           ['conv2d_13[0][0]']
#                                 )
#
#  tf.nn.relu_14 (TFOpLambda)     (None, 480, 320, 32  0           ['conv2d_14[0][0]']
#                                 )
#
#  tf.nn.relu_15 (TFOpLambda)     (None, 480, 320, 32  0           ['conv2d_15[0][0]']
#                                 )
#
#  tf.nn.relu_17 (TFOpLambda)     (None, 240, 160, 32  0           ['conv2d_17[0][0]']
#                                 )
#
#  tf.nn.relu_18 (TFOpLambda)     (None, 240, 160, 32  0           ['conv2d_18[0][0]']
#                                 )
#
#  tf.nn.relu_19 (TFOpLambda)     (None, 240, 160, 32  0           ['conv2d_19[0][0]']
#                                 )
#
#  tf.nn.relu_20 (TFOpLambda)     (None, 240, 160, 32  0           ['conv2d_20[0][0]']
#                                 )
#
#  tf.nn.relu_22 (TFOpLambda)     (None, 120, 80, 32)  0           ['conv2d_22[0][0]']
#
#  tf.nn.relu_23 (TFOpLambda)     (None, 120, 80, 32)  0           ['conv2d_23[0][0]']
#
#  tf.nn.relu_24 (TFOpLambda)     (None, 120, 80, 32)  0           ['conv2d_24[0][0]']
#
#  tf.nn.relu_25 (TFOpLambda)     (None, 120, 80, 32)  0           ['conv2d_25[0][0]']
#
#  tf.nn.relu_26 (TFOpLambda)     (None, 120, 80, 32)  0           ['conv2d_26[0][0]']
#
#  tf.nn.relu_10 (TFOpLambda)     (None, 960, 640, 32  0           ['conv2d_10[0][0]']
#                                 )
#
#  tf.nn.relu_11 (TFOpLambda)     (None, 960, 640, 32  0           ['conv2d_11[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 480, 320, 96  0           ['tf.nn.relu_13[0][0]',
#                                 )                                 'tf.nn.relu_14[0][0]',
#                                                                   'tf.nn.relu_15[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 240, 160, 12  0           ['tf.nn.relu_17[0][0]',
#                                 8)                                'tf.nn.relu_18[0][0]',
#                                                                   'tf.nn.relu_19[0][0]',
#                                                                   'tf.nn.relu_20[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 120, 80, 160  0           ['tf.nn.relu_22[0][0]',
#                                 )                                 'tf.nn.relu_23[0][0]',
#                                                                   'tf.nn.relu_24[0][0]',
#                                                                   'tf.nn.relu_25[0][0]',
#                                                                   'tf.nn.relu_26[0][0]']
#
#  concatenate (Concatenate)      (None, 960, 640, 64  0           ['tf.nn.relu_10[0][0]',
#                                 )                                 'tf.nn.relu_11[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 480, 320, 96  83040       ['concatenate_1[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 240, 160, 12  147584      ['concatenate_2[0][0]']
#                                 8)
#
#  conv2d_27 (Conv2D)             (None, 120, 80, 160  230560      ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_12 (Conv2D)             (None, 960, 640, 64  36928       ['concatenate[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 480, 320, 96  384        ['conv2d_16[0][0]']
#  rmalization)                   )
#
#  batch_normalization_2 (BatchNo  (None, 240, 160, 12  512        ['conv2d_21[0][0]']
#  rmalization)                   8)
#
#  batch_normalization_3 (BatchNo  (None, 120, 80, 160  640        ['conv2d_27[0][0]']
#  rmalization)                   )
#
#  batch_normalization (BatchNorm  (None, 960, 640, 64  256        ['conv2d_12[0][0]']
#  alization)                     )
#
#  tf.nn.relu_16 (TFOpLambda)     (None, 480, 320, 96  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  tf.nn.relu_21 (TFOpLambda)     (None, 240, 160, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  tf.nn.relu_27 (TFOpLambda)     (None, 120, 80, 160  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  tf.nn.relu_12 (TFOpLambda)     (None, 960, 640, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  up_sampling2d_4 (UpSampling2D)  (None, 960, 640, 96  0          ['tf.nn.relu_16[0][0]']
#                                 )
#
#  up_sampling2d_5 (UpSampling2D)  (None, 960, 640, 12  0          ['tf.nn.relu_5[0][0]']
#                                 8)
#
#  max_pooling2d_10 (MaxPooling2D  (None, 480, 320, 32  0          ['tf.nn.relu_1[0][0]']
#  )                              )
#
#  up_sampling2d_6 (UpSampling2D)  (None, 480, 320, 12  0          ['tf.nn.relu_21[0][0]']
#                                 8)
#
#  up_sampling2d_7 (UpSampling2D)  (None, 480, 320, 25  0          ['tf.nn.relu_7[0][0]']
#                                 6)
#
#  max_pooling2d_11 (MaxPooling2D  (None, 240, 160, 32  0          ['tf.nn.relu_1[0][0]']
#  )                              )
#
#  max_pooling2d_12 (MaxPooling2D  (None, 240, 160, 64  0          ['tf.nn.relu_3[0][0]']
#  )                              )
#
#  up_sampling2d_8 (UpSampling2D)  (None, 240, 160, 16  0          ['tf.nn.relu_27[0][0]']
#                                 0)
#
#  up_sampling2d_9 (UpSampling2D)  (None, 240, 160, 51  0          ['tf.nn.relu_9[0][0]']
#                                 2)
#
#  conv2d_28 (Conv2D)             (None, 960, 640, 32  9248        ['tf.nn.relu_1[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 960, 640, 32  27680       ['up_sampling2d_4[0][0]']
#                                 )
#
#  conv2d_30 (Conv2D)             (None, 960, 640, 32  36896       ['up_sampling2d_5[0][0]']
#                                 )
#
#  conv2d_31 (Conv2D)             (None, 960, 640, 32  18464       ['tf.nn.relu_12[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 480, 320, 32  18464       ['tf.nn.relu_3[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 480, 320, 32  9248        ['max_pooling2d_10[0][0]']
#                                 )
#
#  conv2d_35 (Conv2D)             (None, 480, 320, 32  36896       ['up_sampling2d_6[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 480, 320, 32  73760       ['up_sampling2d_7[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 480, 320, 32  27680       ['tf.nn.relu_16[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 240, 160, 32  36896       ['tf.nn.relu_5[0][0]']
#                                 )
#
#  conv2d_40 (Conv2D)             (None, 240, 160, 32  9248        ['max_pooling2d_11[0][0]']
#                                 )
#
#  conv2d_41 (Conv2D)             (None, 240, 160, 32  18464       ['max_pooling2d_12[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 240, 160, 32  46112       ['up_sampling2d_8[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 240, 160, 32  147488      ['up_sampling2d_9[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 240, 160, 32  36896       ['tf.nn.relu_21[0][0]']
#                                 )
#
#  tf.nn.relu_28 (TFOpLambda)     (None, 960, 640, 32  0           ['conv2d_28[0][0]']
#                                 )
#
#  tf.nn.relu_29 (TFOpLambda)     (None, 960, 640, 32  0           ['conv2d_29[0][0]']
#                                 )
#
#  tf.nn.relu_30 (TFOpLambda)     (None, 960, 640, 32  0           ['conv2d_30[0][0]']
#                                 )
#
#  tf.nn.relu_31 (TFOpLambda)     (None, 960, 640, 32  0           ['conv2d_31[0][0]']
#                                 )
#
#  tf.nn.relu_33 (TFOpLambda)     (None, 480, 320, 32  0           ['conv2d_33[0][0]']
#                                 )
#
#  tf.nn.relu_34 (TFOpLambda)     (None, 480, 320, 32  0           ['conv2d_34[0][0]']
#                                 )
#
#  tf.nn.relu_35 (TFOpLambda)     (None, 480, 320, 32  0           ['conv2d_35[0][0]']
#                                 )
#
#  tf.nn.relu_36 (TFOpLambda)     (None, 480, 320, 32  0           ['conv2d_36[0][0]']
#                                 )
#
#  tf.nn.relu_37 (TFOpLambda)     (None, 480, 320, 32  0           ['conv2d_37[0][0]']
#                                 )
#
#  tf.nn.relu_39 (TFOpLambda)     (None, 240, 160, 32  0           ['conv2d_39[0][0]']
#                                 )
#
#  tf.nn.relu_40 (TFOpLambda)     (None, 240, 160, 32  0           ['conv2d_40[0][0]']
#                                 )
#
#  tf.nn.relu_41 (TFOpLambda)     (None, 240, 160, 32  0           ['conv2d_41[0][0]']
#                                 )
#
#  tf.nn.relu_42 (TFOpLambda)     (None, 240, 160, 32  0           ['conv2d_42[0][0]']
#                                 )
#
#  tf.nn.relu_43 (TFOpLambda)     (None, 240, 160, 32  0           ['conv2d_43[0][0]']
#                                 )
#
#  tf.nn.relu_44 (TFOpLambda)     (None, 240, 160, 32  0           ['conv2d_44[0][0]']
#                                 )
#
#  concatenate_4 (Concatenate)    (None, 960, 640, 12  0           ['tf.nn.relu_28[0][0]',
#                                 8)                                'tf.nn.relu_29[0][0]',
#                                                                   'tf.nn.relu_30[0][0]',
#                                                                   'tf.nn.relu_31[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 480, 320, 16  0           ['tf.nn.relu_33[0][0]',
#                                 0)                                'tf.nn.relu_34[0][0]',
#                                                                   'tf.nn.relu_35[0][0]',
#                                                                   'tf.nn.relu_36[0][0]',
#                                                                   'tf.nn.relu_37[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 240, 160, 19  0           ['tf.nn.relu_39[0][0]',
#                                 2)                                'tf.nn.relu_40[0][0]',
#                                                                   'tf.nn.relu_41[0][0]',
#                                                                   'tf.nn.relu_42[0][0]',
#                                                                   'tf.nn.relu_43[0][0]',
#                                                                   'tf.nn.relu_44[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 960, 640, 12  147584      ['concatenate_4[0][0]']
#                                 8)
#
#  conv2d_38 (Conv2D)             (None, 480, 320, 16  230560      ['concatenate_5[0][0]']
#                                 0)
#
#  conv2d_45 (Conv2D)             (None, 240, 160, 19  331968      ['concatenate_6[0][0]']
#                                 2)
#
#  batch_normalization_4 (BatchNo  (None, 960, 640, 12  512        ['conv2d_32[0][0]']
#  rmalization)                   8)
#
#  batch_normalization_5 (BatchNo  (None, 480, 320, 16  640        ['conv2d_38[0][0]']
#  rmalization)                   0)
#
#  batch_normalization_6 (BatchNo  (None, 240, 160, 19  768        ['conv2d_45[0][0]']
#  rmalization)                   2)
#
#  tf.nn.relu_32 (TFOpLambda)     (None, 960, 640, 12  0           ['batch_normalization_4[0][0]']
#                                 8)
#
#  tf.nn.relu_38 (TFOpLambda)     (None, 480, 320, 16  0           ['batch_normalization_5[0][0]']
#                                 0)
#
#  tf.nn.relu_45 (TFOpLambda)     (None, 240, 160, 19  0           ['batch_normalization_6[0][0]']
#                                 2)
#
#  up_sampling2d_10 (UpSampling2D  (None, 960, 640, 16  0          ['tf.nn.relu_38[0][0]']
#  )                              0)
#
#  up_sampling2d_11 (UpSampling2D  (None, 960, 640, 12  0          ['tf.nn.relu_21[0][0]']
#  )                              8)
#
#  up_sampling2d_12 (UpSampling2D  (None, 960, 640, 25  0          ['tf.nn.relu_7[0][0]']
#  )                              6)
#
#  concatenate_7 (Concatenate)    (None, 960, 640, 19  0           ['tf.nn.relu_12[0][0]',
#                                 2)                                'tf.nn.relu_32[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 480, 320, 32  0          ['tf.nn.relu_1[0][0]']
#  )                              )
#
#  up_sampling2d_13 (UpSampling2D  (None, 480, 320, 19  0          ['tf.nn.relu_45[0][0]']
#  )                              2)
#
#  up_sampling2d_14 (UpSampling2D  (None, 480, 320, 16  0          ['tf.nn.relu_27[0][0]']
#  )                              0)
#
#  up_sampling2d_15 (UpSampling2D  (None, 480, 320, 51  0          ['tf.nn.relu_9[0][0]']
#  )                              2)
#
#  concatenate_9 (Concatenate)    (None, 480, 320, 25  0           ['tf.nn.relu_16[0][0]',
#                                 6)                                'tf.nn.relu_38[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 960, 640, 32  9248        ['tf.nn.relu_1[0][0]']
#                                 )
#
#  conv2d_47 (Conv2D)             (None, 960, 640, 32  46112       ['up_sampling2d_10[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 960, 640, 32  36896       ['up_sampling2d_11[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 960, 640, 32  73760       ['up_sampling2d_12[0][0]']
#                                 )
#
#  conv2d_50 (Conv2D)             (None, 960, 640, 32  55328       ['concatenate_7[0][0]']
#                                 )
#
#  conv2d_52 (Conv2D)             (None, 480, 320, 32  18464       ['tf.nn.relu_3[0][0]']
#                                 )
#
#  conv2d_53 (Conv2D)             (None, 480, 320, 32  9248        ['max_pooling2d_13[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 480, 320, 32  55328       ['up_sampling2d_13[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 480, 320, 32  46112       ['up_sampling2d_14[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 480, 320, 32  147488      ['up_sampling2d_15[0][0]']
#                                 )
#
#  conv2d_57 (Conv2D)             (None, 480, 320, 32  73760       ['concatenate_9[0][0]']
#                                 )
#
#  tf.nn.relu_46 (TFOpLambda)     (None, 960, 640, 32  0           ['conv2d_46[0][0]']
#                                 )
#
#  tf.nn.relu_47 (TFOpLambda)     (None, 960, 640, 32  0           ['conv2d_47[0][0]']
#                                 )
#
#  tf.nn.relu_48 (TFOpLambda)     (None, 960, 640, 32  0           ['conv2d_48[0][0]']
#                                 )
#
#  tf.nn.relu_49 (TFOpLambda)     (None, 960, 640, 32  0           ['conv2d_49[0][0]']
#                                 )
#
#  tf.nn.relu_50 (TFOpLambda)     (None, 960, 640, 32  0           ['conv2d_50[0][0]']
#                                 )
#
#  tf.nn.relu_52 (TFOpLambda)     (None, 480, 320, 32  0           ['conv2d_52[0][0]']
#                                 )
#
#  tf.nn.relu_53 (TFOpLambda)     (None, 480, 320, 32  0           ['conv2d_53[0][0]']
#                                 )
#
#  tf.nn.relu_54 (TFOpLambda)     (None, 480, 320, 32  0           ['conv2d_54[0][0]']
#                                 )
#
#  tf.nn.relu_55 (TFOpLambda)     (None, 480, 320, 32  0           ['conv2d_55[0][0]']
#                                 )
#
#  tf.nn.relu_56 (TFOpLambda)     (None, 480, 320, 32  0           ['conv2d_56[0][0]']
#                                 )
#
#  tf.nn.relu_57 (TFOpLambda)     (None, 480, 320, 32  0           ['conv2d_57[0][0]']
#                                 )
#
#  concatenate_8 (Concatenate)    (None, 960, 640, 16  0           ['tf.nn.relu_46[0][0]',
#                                 0)                                'tf.nn.relu_47[0][0]',
#                                                                   'tf.nn.relu_48[0][0]',
#                                                                   'tf.nn.relu_49[0][0]',
#                                                                   'tf.nn.relu_50[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 480, 320, 19  0           ['tf.nn.relu_52[0][0]',
#                                 2)                                'tf.nn.relu_53[0][0]',
#                                                                   'tf.nn.relu_54[0][0]',
#                                                                   'tf.nn.relu_55[0][0]',
#                                                                   'tf.nn.relu_56[0][0]',
#                                                                   'tf.nn.relu_57[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 960, 640, 16  230560      ['concatenate_8[0][0]']
#                                 0)
#
#  conv2d_58 (Conv2D)             (None, 480, 320, 19  331968      ['concatenate_10[0][0]']
#                                 2)
#
#  batch_normalization_7 (BatchNo  (None, 960, 640, 16  640        ['conv2d_51[0][0]']
#  rmalization)                   0)
#
#  batch_normalization_8 (BatchNo  (None, 480, 320, 19  768        ['conv2d_58[0][0]']
#  rmalization)                   2)
#
#  tf.nn.relu_51 (TFOpLambda)     (None, 960, 640, 16  0           ['batch_normalization_7[0][0]']
#                                 0)
#
#  tf.nn.relu_58 (TFOpLambda)     (None, 480, 320, 19  0           ['batch_normalization_8[0][0]']
#                                 2)
#
#  up_sampling2d_16 (UpSampling2D  (None, 960, 640, 19  0          ['tf.nn.relu_58[0][0]']
#  )                              2)
#
#  up_sampling2d_17 (UpSampling2D  (None, 960, 640, 19  0          ['tf.nn.relu_45[0][0]']
#  )                              2)
#
#  up_sampling2d_18 (UpSampling2D  (None, 960, 640, 16  0          ['tf.nn.relu_27[0][0]']
#  )                              0)
#
#  up_sampling2d_19 (UpSampling2D  (None, 960, 640, 51  0          ['tf.nn.relu_9[0][0]']
#  )                              2)
#
#  concatenate_11 (Concatenate)   (None, 960, 640, 35  0           ['tf.nn.relu_12[0][0]',
#                                 2)                                'tf.nn.relu_32[0][0]',
#                                                                   'tf.nn.relu_51[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 960, 640, 32  9248        ['tf.nn.relu_1[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 960, 640, 32  55328       ['up_sampling2d_16[0][0]']
#                                 )
#
#  conv2d_61 (Conv2D)             (None, 960, 640, 32  55328       ['up_sampling2d_17[0][0]']
#                                 )
#
#  conv2d_62 (Conv2D)             (None, 960, 640, 32  46112       ['up_sampling2d_18[0][0]']
#                                 )
#
#  conv2d_63 (Conv2D)             (None, 960, 640, 32  147488      ['up_sampling2d_19[0][0]']
#                                 )
#
#  conv2d_64 (Conv2D)             (None, 960, 640, 32  101408      ['concatenate_11[0][0]']
#                                 )
#
#  tf.nn.relu_59 (TFOpLambda)     (None, 960, 640, 32  0           ['conv2d_59[0][0]']
#                                 )
#
#  tf.nn.relu_60 (TFOpLambda)     (None, 960, 640, 32  0           ['conv2d_60[0][0]']
#                                 )
#
#  tf.nn.relu_61 (TFOpLambda)     (None, 960, 640, 32  0           ['conv2d_61[0][0]']
#                                 )
#
#  tf.nn.relu_62 (TFOpLambda)     (None, 960, 640, 32  0           ['conv2d_62[0][0]']
#                                 )
#
#  tf.nn.relu_63 (TFOpLambda)     (None, 960, 640, 32  0           ['conv2d_63[0][0]']
#                                 )
#
#  tf.nn.relu_64 (TFOpLambda)     (None, 960, 640, 32  0           ['conv2d_64[0][0]']
#                                 )
#
#  concatenate_12 (Concatenate)   (None, 960, 640, 19  0           ['tf.nn.relu_59[0][0]',
#                                 2)                                'tf.nn.relu_60[0][0]',
#                                                                   'tf.nn.relu_61[0][0]',
#                                                                   'tf.nn.relu_62[0][0]',
#                                                                   'tf.nn.relu_63[0][0]',
#                                                                   'tf.nn.relu_64[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 960, 640, 19  331968      ['concatenate_12[0][0]']
#                                 2)
#
#  batch_normalization_9 (BatchNo  (None, 960, 640, 19  768        ['conv2d_65[0][0]']
#  rmalization)                   2)
#
#  tf.nn.relu_65 (TFOpLambda)     (None, 960, 640, 19  0           ['batch_normalization_9[0][0]']
#                                 2)
#
#  conv2d_70 (Conv2D)             (None, 480, 320, 1)  1729        ['tf.nn.relu_58[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 240, 160, 1)  1729        ['tf.nn.relu_45[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 120, 80, 1)   1441        ['tf.nn.relu_27[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 60, 40, 1)    4609        ['tf.nn.relu_9[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 960, 640, 1)  65          ['tf.nn.relu_12[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 960, 640, 1)  129         ['tf.nn.relu_32[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 960, 640, 1)  161         ['tf.nn.relu_51[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 960, 640, 1)  193         ['tf.nn.relu_65[0][0]']
#
#  up_sampling2d_20 (UpSampling2D  (None, 960, 640, 1)  0          ['conv2d_70[0][0]']
#  )
#
#  up_sampling2d_21 (UpSampling2D  (None, 960, 640, 1)  0          ['conv2d_71[0][0]']
#  )
#
#  up_sampling2d_22 (UpSampling2D  (None, 960, 640, 1)  0          ['conv2d_72[0][0]']
#  )
#
#  up_sampling2d_23 (UpSampling2D  (None, 960, 640, 1)  0          ['conv2d_73[0][0]']
#  )
#
#  tf.math.sigmoid (TFOpLambda)   (None, 960, 640, 1)  0           ['conv2d_66[0][0]']
#
#  tf.math.sigmoid_1 (TFOpLambda)  (None, 960, 640, 1)  0          ['conv2d_67[0][0]']
#
#  tf.math.sigmoid_2 (TFOpLambda)  (None, 960, 640, 1)  0          ['conv2d_68[0][0]']
#
#  tf.math.sigmoid_3 (TFOpLambda)  (None, 960, 640, 1)  0          ['conv2d_69[0][0]']
#
#  tf.math.sigmoid_4 (TFOpLambda)  (None, 960, 640, 1)  0          ['up_sampling2d_20[0][0]']
#
#  tf.math.sigmoid_5 (TFOpLambda)  (None, 960, 640, 1)  0          ['up_sampling2d_21[0][0]']
#
#  tf.math.sigmoid_6 (TFOpLambda)  (None, 960, 640, 1)  0          ['up_sampling2d_22[0][0]']
#
#  tf.math.sigmoid_7 (TFOpLambda)  (None, 960, 640, 1)  0          ['up_sampling2d_23[0][0]']
#
# ==================================================================================================
# Total params: 8,887,528
# Trainable params: 8,884,584
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %% [markdown]
# 학습+예측 이미지
# =========================

# %%
model.compile(optimizer='adam', loss=Focal_IoU, metrics=['accuracy'])
print(model.name,"모델이 컴파일 되었습니다.")
if (os.path.exists(f'{data_dir}/{model.name}.h5')):
  print('해당모델과 같은 이름의 모델이 학습되고 있습니다.')
if (os.path.exists(f'/content/drive/MyDrive/data/model/{model.name}-H{IMAGE_HEIGHT}-W{IMAGE_WIDTH}-{BATCH_SIZE}')):
  print('해당모델과 같은 이름의 모델이 이전에 학습된 적이 있습니다.')
#model.summary()
print('Model Outputs :' , model.output_names)
# Out:
# LayerUNET-L5-F32-DSV 모델이 컴파일 되었습니다.
# Model Outputs : ['tf.math.sigmoid', 'tf.math.sigmoid_1', 'tf.math.sigmoid_2', 'tf.math.sigmoid_3', 'tf.math.sigmoid_4', 'tf.math.sigmoid_5', 'tf.math.sigmoid_6', 'tf.math.sigmoid_7']

# %%
#학습부분
print(f'Train Data:{NUM_TRAIN}')
print(f'Valid Data:{NUM_VALID}')
print(f'Epochs:{NUM_OF_EPOCHS}')
print(f'Batch Size:{BATCH_SIZE}')
print(f'U-NET Level:{UNet_level}')
print(f'Model Name:{model.name}')
print(f'Loss:{model.loss}')
print(f'Dataset Name:{data_dir.split("/")[-1]}')
print(f'I/O Image Size (H * W):{IMAGE_HEIGHT} * {IMAGE_WIDTH}')

cp_dir = f'{data_dir}/{model.name}.h5'

mc = tf.keras.callbacks.ModelCheckpoint(filepath=cp_dir, 
                                        save_best_only=True,
                                        verbose=1
                                        )

history = model.fit(train_dataset,
                    steps_per_epoch=EPOCH_STEP_TRAIN,
                    validation_data=valid_dataset,
                    validation_steps=EPOCH_STEP_VALID,
                    epochs=NUM_OF_EPOCHS,
                    callbacks=[mc]
                    )
# Out:
# Train Data:96
# Valid Data:24
# Epochs:50
# Batch Size:1
# U-NET Level:5
# Model Name:LayerUNET-L5-F32-DSV
# Loss:<function Focal_IoU at 0x7fd314034310>
# Dataset Name:mulimedia
# I/O Image Size (H * W):960 * 640
# Epoch 1/50
# 96/96 [==============================] - ETA: 0s - loss: 7.2795 - tf.math.sigmoid_loss: 0.9265 - tf.math.sigmoid_1_loss: 0.8165 - tf.math.sigmoid_2_loss: 0.7815 - tf.math.sigmoid_3_loss: 0.8737 - tf.math.sigmoid_4_loss: 0.7399 - tf.math.sigmoid_5_loss: 0.7360 - tf.math.sigmoid_6_loss: 0.7329 - tf.math.sigmoid_7_loss: 1.6725 - tf.math.sigmoid_accuracy: 0.9453 - tf.math.sigmoid_1_accuracy: 0.9066 - tf.math.sigmoid_2_accuracy: 0.8986 - tf.math.sigmoid_3_accuracy: 0.9211 - tf.math.sigmoid_4_accuracy: 0.9540 - tf.math.sigmoid_5_accuracy: 0.9542 - tf.math.sigmoid_6_accuracy: 0.9553 - tf.math.sigmoid_7_accuracy: 0.9472
# Epoch 1: val_loss improved from inf to 11.90864, saving model to /content/drive/MyDrive/newstudy/mulimedia/LayerUNET-L5-F32-DSV.h5
# 96/96 [==============================] - 60s 349ms/step - loss: 7.2795 - tf.math.sigmoid_loss: 0.9265 - tf.math.sigmoid_1_loss: 0.8165 - tf.math.sigmoid_2_loss: 0.7815 - tf.math.sigmoid_3_loss: 0.8737 - tf.math.sigmoid_4_loss: 0.7399 - tf.math.sigmoid_5_loss: 0.7360 - tf.math.sigmoid_6_loss: 0.7329 - tf.math.sigmoid_7_loss: 1.6725 - tf.math.sigmoid_accuracy: 0.9453 - tf.math.sigmoid_1_accuracy: 0.9066 - tf.math.sigmoid_2_accuracy: 0.8986 - tf.math.sigmoid_3_accuracy: 0.9211 - tf.math.sigmoid_4_accuracy: 0.9540 - tf.math.sigmoid_5_accuracy: 0.9542 - tf.math.sigmoid_6_accuracy: 0.9553 - tf.math.sigmoid_7_accuracy: 0.9472 - val_loss: 11.9086 - val_tf.math.sigmoid_loss: 0.9566 - val_tf.math.sigmoid_1_loss: 1.6004 - val_tf.math.sigmoid_2_loss: 1.5066 - val_tf.math.sigmoid_3_loss: 1.1869 - val_tf.math.sigmoid_4_loss: 1.6527 - val_tf.math.sigmoid_5_loss: 1.6312 - val_tf.math.sigmoid_6_loss: 1.6841 - val_tf.math.sigmoid_7_loss: 1.6901 - val_tf.math.sigmoid_accuracy: 0.9681 - val_tf.math.sigmoid_1_accuracy: 0.4353 - val_tf.math.sigmoid_2_accuracy: 0.6141 - val_tf.math.sigmoid_3_accuracy: 0.9553 - val_tf.math.sigmoid_4_accuracy: 0.9553 - val_tf.math.sigmoid_5_accuracy: 0.9553 - val_tf.math.sigmoid_6_accuracy: 0.9553 - val_tf.math.sigmoid_7_accuracy: 0.9553
# Epoch 2/50
# 96/96 [==============================] - ETA: 0s - loss: 3.6143 - tf.math.sigmoid_loss: 0.5134 - tf.math.sigmoid_1_loss: 0.2861 - tf.math.sigmoid_2_loss: 0.2221 - tf.math.sigmoid_3_loss: 0.2028 - tf.math.sigmoid_4_loss: 0.1969 - tf.math.sigmoid_5_loss: 0.2350 - tf.math.sigmoid_6_loss: 0.2816 - tf.math.sigmoid_7_loss: 1.6764 - tf.math.sigmoid_accuracy: 0.9845 - tf.math.sigmoid_1_accuracy: 0.9910 - tf.math.sigmoid_2_accuracy: 0.9924 - tf.math.sigmoid_3_accuracy: 0.9927 - tf.math.sigmoid_4_accuracy: 0.9923 - tf.math.sigmoid_5_accuracy: 0.9907 - tf.math.sigmoid_6_accuracy: 0.9885 - tf.math.sigmoid_7_accuracy: 0.9562
# Epoch 2: val_loss improved from 11.90864 to 9.54105, saving model to /content/drive/MyDrive/newstudy/mulimedia/LayerUNET-L5-F32-DSV.h5
# 96/96 [==============================] - 32s 335ms/step - loss: 3.6143 - tf.math.sigmoid_loss: 0.5134 - tf.math.sigmoid_1_loss: 0.2861 - tf.math.sigmoid_2_loss: 0.2221 - tf.math.sigmoid_3_loss: 0.2028 - tf.math.sigmoid_4_loss: 0.1969 - tf.math.sigmoid_5_loss: 0.2350 - tf.math.sigmoid_6_loss: 0.2816 - tf.math.sigmoid_7_loss: 1.6764 - tf.math.sigmoid_accuracy: 0.9845 - tf.math.sigmoid_1_accuracy: 0.9910 - tf.math.sigmoid_2_accuracy: 0.9924 - tf.math.sigmoid_3_accuracy: 0.9927 - tf.math.sigmoid_4_accuracy: 0.9923 - tf.math.sigmoid_5_accuracy: 0.9907 - tf.math.sigmoid_6_accuracy: 0.9885 - tf.math.sigmoid_7_accuracy: 0.9562 - val_loss: 9.5410 - val_tf.math.sigmoid_loss: 0.7414 - val_tf.math.sigmoid_1_loss: 0.2705 - val_tf.math.sigmoid_2_loss: 0.6311 - val_tf.math.sigmoid_3_loss: 1.3076 - val_tf.math.sigmoid_4_loss: 1.5787 - val_tf.math.sigmoid_5_loss: 1.6362 - val_tf.math.sigmoid_6_loss: 1.6855 - val_tf.math.sigmoid_7_loss: 1.6901 - val_tf.math.sigmoid_accuracy: 0.9813 - val_tf.math.sigmoid_1_accuracy: 0.9928 - val_tf.math.sigmoid_2_accuracy: 0.9812 - val_tf.math.sigmoid_3_accuracy: 0.9553 - val_tf.math.sigmoid_4_accuracy: 0.9553 - val_tf.math.sigmoid_5_accuracy: 0.9553 - val_tf.math.sigmoid_6_accuracy: 0.9553 - val_tf.math.sigmoid_7_accuracy: 0.9553
# Epoch 3/50
# 96/96 [==============================] - ETA: 0s - loss: 2.2989 - tf.math.sigmoid_loss: 0.3111 - tf.math.sigmoid_1_loss: 0.1701 - tf.math.sigmoid_2_loss: 0.1327 - tf.math.sigmoid_3_loss: 0.1260 - tf.math.sigmoid_4_loss: 0.1256 - tf.math.sigmoid_5_loss: 0.1364 - tf.math.sigmoid_6_loss: 0.1687 - tf.math.sigmoid_7_loss: 1.1284 - tf.math.sigmoid_accuracy: 0.9894 - tf.math.sigmoid_1_accuracy: 0.9942 - tf.math.sigmoid_2_accuracy: 0.9953 - tf.math.sigmoid_3_accuracy: 0.9954 - tf.math.sigmoid_4_accuracy: 0.9953 - tf.math.sigmoid_5_accuracy: 0.9948 - tf.math.sigmoid_6_accuracy: 0.9935 - tf.math.sigmoid_7_accuracy: 0.9673
# Epoch 3: val_loss improved from 9.54105 to 7.05738, saving model to /content/drive/MyDrive/newstudy/mulimedia/LayerUNET-L5-F32-DSV.h5
# 96/96 [==============================] - 32s 335ms/step - loss: 2.2989 - tf.math.sigmoid_loss: 0.3111 - tf.math.sigmoid_1_loss: 0.1701 - tf.math.sigmoid_2_loss: 0.1327 - tf.math.sigmoid_3_loss: 0.1260 - tf.math.sigmoid_4_loss: 0.1256 - tf.math.sigmoid_5_loss: 0.1364 - tf.math.sigmoid_6_loss: 0.1687 - tf.math.sigmoid_7_loss: 1.1284 - tf.math.sigmoid_accuracy: 0.9894 - tf.math.sigmoid_1_accuracy: 0.9942 - tf.math.sigmoid_2_accuracy: 0.9953 - tf.math.sigmoid_3_accuracy: 0.9954 - tf.math.sigmoid_4_accuracy: 0.9953 - tf.math.sigmoid_5_accuracy: 0.9948 - tf.math.sigmoid_6_accuracy: 0.9935 - tf.math.sigmoid_7_accuracy: 0.9673 - val_loss: 7.0574 - val_tf.math.sigmoid_loss: 0.6994 - val_tf.math.sigmoid_1_loss: 0.4920 - val_tf.math.sigmoid_2_loss: 0.2403 - val_tf.math.sigmoid_3_loss: 1.2290 - val_tf.math.sigmoid_4_loss: 1.2658 - val_tf.math.sigmoid_5_loss: 1.2671 - val_tf.math.sigmoid_6_loss: 1.4594 - val_tf.math.sigmoid_7_loss: 0.4044 - val_tf.math.sigmoid_accuracy: 0.9677 - val_tf.math.sigmoid_1_accuracy: 0.9792 - val_tf.math.sigmoid_2_accuracy: 0.9914 - val_tf.math.sigmoid_3_accuracy: 0.9553 - val_tf.math.sigmoid_4_accuracy: 0.9553 - val_tf.math.sigmoid_5_accuracy: 0.9553 - val_tf.math.sigmoid_6_accuracy: 0.9553 - val_tf.math.sigmoid_7_accuracy: 0.9846
# Epoch 4/50
# 96/96 [==============================] - ETA: 0s - loss: 1.3214 - tf.math.sigmoid_loss: 0.2915 - tf.math.sigmoid_1_loss: 0.1493 - tf.math.sigmoid_2_loss: 0.1233 - tf.math.sigmoid_3_loss: 0.1174 - tf.math.sigmoid_4_loss: 0.1169 - tf.math.sigmoid_5_loss: 0.1268 - tf.math.sigmoid_6_loss: 0.1464 - tf.math.sigmoid_7_loss: 0.2498 - tf.math.sigmoid_accuracy: 0.9894 - tf.math.sigmoid_1_accuracy: 0.9947 - tf.math.sigmoid_2_accuracy: 0.9955 - tf.math.sigmoid_3_accuracy: 0.9956 - tf.math.sigmoid_4_accuracy: 0.9956 - tf.math.sigmoid_5_accuracy: 0.9952 - tf.math.sigmoid_6_accuracy: 0.9944 - tf.math.sigmoid_7_accuracy: 0.9901
# Epoch 4: val_loss improved from 7.05738 to 4.72358, saving model to /content/drive/MyDrive/newstudy/mulimedia/LayerUNET-L5-F32-DSV.h5
# 96/96 [==============================] - 32s 336ms/step - loss: 1.3214 - tf.math.sigmoid_loss: 0.2915 - tf.math.sigmoid_1_loss: 0.1493 - tf.math.sigmoid_2_loss: 0.1233 - tf.math.sigmoid_3_loss: 0.1174 - tf.math.sigmoid_4_loss: 0.1169 - tf.math.sigmoid_5_loss: 0.1268 - tf.math.sigmoid_6_loss: 0.1464 - tf.math.sigmoid_7_loss: 0.2498 - tf.math.sigmoid_accuracy: 0.9894 - tf.math.sigmoid_1_accuracy: 0.9947 - tf.math.sigmoid_2_accuracy: 0.9955 - tf.math.sigmoid_3_accuracy: 0.9956 - tf.math.sigmoid_4_accuracy: 0.9956 - tf.math.sigmoid_5_accuracy: 0.9952 - tf.math.sigmoid_6_accuracy: 0.9944 - tf.math.sigmoid_7_accuracy: 0.9901 - val_loss: 4.7236 - val_tf.math.sigmoid_loss: 0.2602 - val_tf.math.sigmoid_1_loss: 0.1400 - val_tf.math.sigmoid_2_loss: 0.1152 - val_tf.math.sigmoid_3_loss: 1.0267 - val_tf.math.sigmoid_4_loss: 0.9249 - val_tf.math.sigmoid_5_loss: 0.8141 - val_tf.math.sigmoid_6_loss: 1.2580 - val_tf.math.sigmoid_7_loss: 0.1844 - val_tf.math.sigmoid_accuracy: 0.9899 - val_tf.math.sigmoid_1_accuracy: 0.9951 - val_tf.math.sigmoid_2_accuracy: 0.9958 - val_tf.math.sigmoid_3_accuracy: 0.9562 - val_tf.math.sigmoid_4_accuracy: 0.9626 - val_tf.math.sigmoid_5_accuracy: 0.9664 - val_tf.math.sigmoid_6_accuracy: 0.9553 - val_tf.math.sigmoid_7_accuracy: 0.9928
# Epoch 5/50
# 96/96 [==============================] - ETA: 0s - loss: 1.0653 - tf.math.sigmoid_loss: 0.2330 - tf.math.sigmoid_1_loss: 0.1135 - tf.math.sigmoid_2_loss: 0.1007 - tf.math.sigmoid_3_loss: 0.0992 - tf.math.sigmoid_4_loss: 0.0992 - tf.math.sigmoid_5_loss: 0.1057 - tf.math.sigmoid_6_loss: 0.1231 - tf.math.sigmoid_7_loss: 0.1910 - tf.math.sigmoid_accuracy: 0.9917 - tf.math.sigmoid_1_accuracy: 0.9960 - tf.math.sigmoid_2_accuracy: 0.9963 - tf.math.sigmoid_3_accuracy: 0.9963 - tf.math.sigmoid_4_accuracy: 0.9963 - tf.math.sigmoid_5_accuracy: 0.9960 - tf.math.sigmoid_6_accuracy: 0.9953 - tf.math.sigmoid_7_accuracy: 0.9926
# Epoch 5: val_loss improved from 4.72358 to 3.14616, saving model to /content/drive/MyDrive/newstudy/mulimedia/LayerUNET-L5-F32-DSV.h5
# 96/96 [==============================] - 32s 338ms/step - loss: 1.0653 - tf.math.sigmoid_loss: 0.2330 - tf.math.sigmoid_1_loss: 0.1135 - tf.math.sigmoid_2_loss: 0.1007 - tf.math.sigmoid_3_loss: 0.0992 - tf.math.sigmoid_4_loss: 0.0992 - tf.math.sigmoid_5_loss: 0.1057 - tf.math.sigmoid_6_loss: 0.1231 - tf.math.sigmoid_7_loss: 0.1910 - tf.math.sigmoid_accuracy: 0.9917 - tf.math.sigmoid_1_accuracy: 0.9960 - tf.math.sigmoid_2_accuracy: 0.9963 - tf.math.sigmoid_3_accuracy: 0.9963 - tf.math.sigmoid_4_accuracy: 0.9963 - tf.math.sigmoid_5_accuracy: 0.9960 - tf.math.sigmoid_6_accuracy: 0.9953 - tf.math.sigmoid_7_accuracy: 0.9926 - val_loss: 3.1462 - val_tf.math.sigmoid_loss: 0.2701 - val_tf.math.sigmoid_1_loss: 0.1388 - val_tf.math.sigmoid_2_loss: 0.1107 - val_tf.math.sigmoid_3_loss: 0.6441 - val_tf.math.sigmoid_4_loss: 0.5137 - val_tf.math.sigmoid_5_loss: 0.4698 - val_tf.math.sigmoid_6_loss: 0.8282 - val_tf.math.sigmoid_7_loss: 0.1709 - val_tf.math.sigmoid_accuracy: 0.9894 - val_tf.math.sigmoid_1_accuracy: 0.9951 - val_tf.math.sigmoid_2_accuracy: 0.9959 - val_tf.math.sigmoid_3_accuracy: 0.9735 - val_tf.math.sigmoid_4_accuracy: 0.9810 - val_tf.math.sigmoid_5_accuracy: 0.9816 - val_tf.math.sigmoid_6_accuracy: 0.9646 - val_tf.math.sigmoid_7_accuracy: 0.9934
# Epoch 6/50
# 96/96 [==============================] - ETA: 0s - loss: 0.9803 - tf.math.sigmoid_loss: 0.2108 - tf.math.sigmoid_1_loss: 0.1044 - tf.math.sigmoid_2_loss: 0.0950 - tf.math.sigmoid_3_loss: 0.0943 - tf.math.sigmoid_4_loss: 0.0942 - tf.math.sigmoid_5_loss: 0.0997 - tf.math.sigmoid_6_loss: 0.1138 - tf.math.sigmoid_7_loss: 0.1681 - tf.math.sigmoid_accuracy: 0.9924 - tf.math.sigmoid_1_accuracy: 0.9963 - tf.math.sigmoid_2_accuracy: 0.9965 - tf.math.sigmoid_3_accuracy: 0.9965 - tf.math.sigmoid_4_accuracy: 0.9965 - tf.math.sigmoid_5_accuracy: 0.9963 - tf.math.sigmoid_6_accuracy: 0.9957 - tf.math.sigmoid_7_accuracy: 0.9937
# Epoch 6: val_loss improved from 3.14616 to 1.85139, saving model to /content/drive/MyDrive/newstudy/mulimedia/LayerUNET-L5-F32-DSV.h5
# 96/96 [==============================] - 33s 340ms/step - loss: 0.9803 - tf.math.sigmoid_loss: 0.2108 - tf.math.sigmoid_1_loss: 0.1044 - tf.math.sigmoid_2_loss: 0.0950 - tf.math.sigmoid_3_loss: 0.0943 - tf.math.sigmoid_4_loss: 0.0942 - tf.math.sigmoid_5_loss: 0.0997 - tf.math.sigmoid_6_loss: 0.1138 - tf.math.sigmoid_7_loss: 0.1681 - tf.math.sigmoid_accuracy: 0.9924 - tf.math.sigmoid_1_accuracy: 0.9963 - tf.math.sigmoid_2_accuracy: 0.9965 - tf.math.sigmoid_3_accuracy: 0.9965 - tf.math.sigmoid_4_accuracy: 0.9965 - tf.math.sigmoid_5_accuracy: 0.9963 - tf.math.sigmoid_6_accuracy: 0.9957 - tf.math.sigmoid_7_accuracy: 0.9937 - val_loss: 1.8514 - val_tf.math.sigmoid_loss: 0.2128 - val_tf.math.sigmoid_1_loss: 0.1265 - val_tf.math.sigmoid_2_loss: 0.1090 - val_tf.math.sigmoid_3_loss: 0.3024 - val_tf.math.sigmoid_4_loss: 0.2281 - val_tf.math.sigmoid_5_loss: 0.3162 - val_tf.math.sigmoid_6_loss: 0.3938 - val_tf.math.sigmoid_7_loss: 0.1627 - val_tf.math.sigmoid_accuracy: 0.9923 - val_tf.math.sigmoid_1_accuracy: 0.9954 - val_tf.math.sigmoid_2_accuracy: 0.9960 - val_tf.math.sigmoid_3_accuracy: 0.9893 - val_tf.math.sigmoid_4_accuracy: 0.9918 - val_tf.math.sigmoid_5_accuracy: 0.9882 - val_tf.math.sigmoid_6_accuracy: 0.9872 - val_tf.math.sigmoid_7_accuracy: 0.9938
# Epoch 7/50
# 96/96 [==============================] - ETA: 0s - loss: 0.9188 - tf.math.sigmoid_loss: 0.1865 - tf.math.sigmoid_1_loss: 0.0978 - tf.math.sigmoid_2_loss: 0.0908 - tf.math.sigmoid_3_loss: 0.0900 - tf.math.sigmoid_4_loss: 0.0904 - tf.math.sigmoid_5_loss: 0.0951 - tf.math.sigmoid_6_loss: 0.1077 - tf.math.sigmoid_7_loss: 0.1604 - tf.math.sigmoid_accuracy: 0.9932 - tf.math.sigmoid_1_accuracy: 0.9965 - tf.math.sigmoid_2_accuracy: 0.9966 - tf.math.sigmoid_3_accuracy: 0.9966 - tf.math.sigmoid_4_accuracy: 0.9966 - tf.math.sigmoid_5_accuracy: 0.9964 - tf.math.sigmoid_6_accuracy: 0.9959 - tf.math.sigmoid_7_accuracy: 0.9939
# Epoch 7: val_loss improved from 1.85139 to 1.24542, saving model to /content/drive/MyDrive/newstudy/mulimedia/LayerUNET-L5-F32-DSV.h5
# 96/96 [==============================] - 32s 335ms/step - loss: 0.9188 - tf.math.sigmoid_loss: 0.1865 - tf.math.sigmoid_1_loss: 0.0978 - tf.math.sigmoid_2_loss: 0.0908 - tf.math.sigmoid_3_loss: 0.0900 - tf.math.sigmoid_4_loss: 0.0904 - tf.math.sigmoid_5_loss: 0.0951 - tf.math.sigmoid_6_loss: 0.1077 - tf.math.sigmoid_7_loss: 0.1604 - tf.math.sigmoid_accuracy: 0.9932 - tf.math.sigmoid_1_accuracy: 0.9965 - tf.math.sigmoid_2_accuracy: 0.9966 - tf.math.sigmoid_3_accuracy: 0.9966 - tf.math.sigmoid_4_accuracy: 0.9966 - tf.math.sigmoid_5_accuracy: 0.9964 - tf.math.sigmoid_6_accuracy: 0.9959 - tf.math.sigmoid_7_accuracy: 0.9939 - val_loss: 1.2454 - val_tf.math.sigmoid_loss: 0.2188 - val_tf.math.sigmoid_1_loss: 0.1265 - val_tf.math.sigmoid_2_loss: 0.0956 - val_tf.math.sigmoid_3_loss: 0.1246 - val_tf.math.sigmoid_4_loss: 0.1113 - val_tf.math.sigmoid_5_loss: 0.1563 - val_tf.math.sigmoid_6_loss: 0.2481 - val_tf.math.sigmoid_7_loss: 0.1642 - val_tf.math.sigmoid_accuracy: 0.9917 - val_tf.math.sigmoid_1_accuracy: 0.9957 - val_tf.math.sigmoid_2_accuracy: 0.9964 - val_tf.math.sigmoid_3_accuracy: 0.9956 - val_tf.math.sigmoid_4_accuracy: 0.9959 - val_tf.math.sigmoid_5_accuracy: 0.9942 - val_tf.math.sigmoid_6_accuracy: 0.9944 - val_tf.math.sigmoid_7_accuracy: 0.9935
# Epoch 8/50
# 96/96 [==============================] - ETA: 0s - loss: 0.8877 - tf.math.sigmoid_loss: 0.1747 - tf.math.sigmoid_1_loss: 0.0955 - tf.math.sigmoid_2_loss: 0.0890 - tf.math.sigmoid_3_loss: 0.0881 - tf.math.sigmoid_4_loss: 0.0884 - tf.math.sigmoid_5_loss: 0.0923 - tf.math.sigmoid_6_loss: 0.1039 - tf.math.sigmoid_7_loss: 0.1557 - tf.math.sigmoid_accuracy: 0.9937 - tf.math.sigmoid_1_accuracy: 0.9965 - tf.math.sigmoid_2_accuracy: 0.9967 - tf.math.sigmoid_3_accuracy: 0.9967 - tf.math.sigmoid_4_accuracy: 0.9967 - tf.math.sigmoid_5_accuracy: 0.9965 - tf.math.sigmoid_6_accuracy: 0.9961 - tf.math.sigmoid_7_accuracy: 0.9941
# Epoch 8: val_loss improved from 1.24542 to 1.02091, saving model to /content/drive/MyDrive/newstudy/mulimedia/LayerUNET-L5-F32-DSV.h5
# 96/96 [==============================] - 32s 336ms/step - loss: 0.8877 - tf.math.sigmoid_loss: 0.1747 - tf.math.sigmoid_1_loss: 0.0955 - tf.math.sigmoid_2_loss: 0.0890 - tf.math.sigmoid_3_loss: 0.0881 - tf.math.sigmoid_4_loss: 0.0884 - tf.math.sigmoid_5_loss: 0.0923 - tf.math.sigmoid_6_loss: 0.1039 - tf.math.sigmoid_7_loss: 0.1557 - tf.math.sigmoid_accuracy: 0.9937 - tf.math.sigmoid_1_accuracy: 0.9965 - tf.math.sigmoid_2_accuracy: 0.9967 - tf.math.sigmoid_3_accuracy: 0.9967 - tf.math.sigmoid_4_accuracy: 0.9967 - tf.math.sigmoid_5_accuracy: 0.9965 - tf.math.sigmoid_6_accuracy: 0.9961 - tf.math.sigmoid_7_accuracy: 0.9941 - val_loss: 1.0209 - val_tf.math.sigmoid_loss: 0.2110 - val_tf.math.sigmoid_1_loss: 0.1045 - val_tf.math.sigmoid_2_loss: 0.0911 - val_tf.math.sigmoid_3_loss: 0.0984 - val_tf.math.sigmoid_4_loss: 0.0961 - val_tf.math.sigmoid_5_loss: 0.1237 - val_tf.math.sigmoid_6_loss: 0.1431 - val_tf.math.sigmoid_7_loss: 0.1531 - val_tf.math.sigmoid_accuracy: 0.9921 - val_tf.math.sigmoid_1_accuracy: 0.9961 - val_tf.math.sigmoid_2_accuracy: 0.9965 - val_tf.math.sigmoid_3_accuracy: 0.9963 - val_tf.math.sigmoid_4_accuracy: 0.9964 - val_tf.math.sigmoid_5_accuracy: 0.9953 - val_tf.math.sigmoid_6_accuracy: 0.9955 - val_tf.math.sigmoid_7_accuracy: 0.9941
# Epoch 9/50
# 96/96 [==============================] - ETA: 0s - loss: 0.8579 - tf.math.sigmoid_loss: 0.1632 - tf.math.sigmoid_1_loss: 0.0924 - tf.math.sigmoid_2_loss: 0.0869 - tf.math.sigmoid_3_loss: 0.0861 - tf.math.sigmoid_4_loss: 0.0868 - tf.math.sigmoid_5_loss: 0.0908 - tf.math.sigmoid_6_loss: 0.1018 - tf.math.sigmoid_7_loss: 0.1500 - tf.math.sigmoid_accuracy: 0.9941 - tf.math.sigmoid_1_accuracy: 0.9966 - tf.math.sigmoid_2_accuracy: 0.9968 - tf.math.sigmoid_3_accuracy: 0.9968 - tf.math.sigmoid_4_accuracy: 0.9968 - tf.math.sigmoid_5_accuracy: 0.9966 - tf.math.sigmoid_6_accuracy: 0.9962 - tf.math.sigmoid_7_accuracy: 0.9944
# Epoch 9: val_loss improved from 1.02091 to 0.88208, saving model to /content/drive/MyDrive/newstudy/mulimedia/LayerUNET-L5-F32-DSV.h5
# 96/96 [==============================] - 32s 339ms/step - loss: 0.8579 - tf.math.sigmoid_loss: 0.1632 - tf.math.sigmoid_1_loss: 0.0924 - tf.math.sigmoid_2_loss: 0.0869 - tf.math.sigmoid_3_loss: 0.0861 - tf.math.sigmoid_4_loss: 0.0868 - tf.math.sigmoid_5_loss: 0.0908 - tf.math.sigmoid_6_loss: 0.1018 - tf.math.sigmoid_7_loss: 0.1500 - tf.math.sigmoid_accuracy: 0.9941 - tf.math.sigmoid_1_accuracy: 0.9966 - tf.math.sigmoid_2_accuracy: 0.9968 - tf.math.sigmoid_3_accuracy: 0.9968 - tf.math.sigmoid_4_accuracy: 0.9968 - tf.math.sigmoid_5_accuracy: 0.9966 - tf.math.sigmoid_6_accuracy: 0.9962 - tf.math.sigmoid_7_accuracy: 0.9944 - val_loss: 0.8821 - val_tf.math.sigmoid_loss: 0.1570 - val_tf.math.sigmoid_1_loss: 0.0949 - val_tf.math.sigmoid_2_loss: 0.0847 - val_tf.math.sigmoid_3_loss: 0.0853 - val_tf.math.sigmoid_4_loss: 0.0881 - val_tf.math.sigmoid_5_loss: 0.1046 - val_tf.math.sigmoid_6_loss: 0.1142 - val_tf.math.sigmoid_7_loss: 0.1533 - val_tf.math.sigmoid_accuracy: 0.9942 - val_tf.math.sigmoid_1_accuracy: 0.9966 - val_tf.math.sigmoid_2_accuracy: 0.9968 - val_tf.math.sigmoid_3_accuracy: 0.9968 - val_tf.math.sigmoid_4_accuracy: 0.9967 - val_tf.math.sigmoid_5_accuracy: 0.9961 - val_tf.math.sigmoid_6_accuracy: 0.9961 - val_tf.math.sigmoid_7_accuracy: 0.9940
# Epoch 10/50
# 96/96 [==============================] - ETA: 0s - loss: 0.8290 - tf.math.sigmoid_loss: 0.1525 - tf.math.sigmoid_1_loss: 0.0897 - tf.math.sigmoid_2_loss: 0.0848 - tf.math.sigmoid_3_loss: 0.0839 - tf.math.sigmoid_4_loss: 0.0846 - tf.math.sigmoid_5_loss: 0.0881 - tf.math.sigmoid_6_loss: 0.0981 - tf.math.sigmoid_7_loss: 0.1473 - tf.math.sigmoid_accuracy: 0.9945 - tf.math.sigmoid_1_accuracy: 0.9967 - tf.math.sigmoid_2_accuracy: 0.9968 - tf.math.sigmoid_3_accuracy: 0.9969 - tf.math.sigmoid_4_accuracy: 0.9968 - tf.math.sigmoid_5_accuracy: 0.9967 - tf.math.sigmoid_6_accuracy: 0.9963 - tf.math.sigmoid_7_accuracy: 0.9945
# Epoch 10: val_loss improved from 0.88208 to 0.87259, saving model to /content/drive/MyDrive/newstudy/mulimedia/LayerUNET-L5-F32-DSV.h5
# 96/96 [==============================] - 32s 336ms/step - loss: 0.8290 - tf.math.sigmoid_loss: 0.1525 - tf.math.sigmoid_1_loss: 0.0897 - tf.math.sigmoid_2_loss: 0.0848 - tf.math.sigmoid_3_loss: 0.0839 - tf.math.sigmoid_4_loss: 0.0846 - tf.math.sigmoid_5_loss: 0.0881 - tf.math.sigmoid_6_loss: 0.0981 - tf.math.sigmoid_7_loss: 0.1473 - tf.math.sigmoid_accuracy: 0.9945 - tf.math.sigmoid_1_accuracy: 0.9967 - tf.math.sigmoid_2_accuracy: 0.9968 - tf.math.sigmoid_3_accuracy: 0.9969 - tf.math.sigmoid_4_accuracy: 0.9968 - tf.math.sigmoid_5_accuracy: 0.9967 - tf.math.sigmoid_6_accuracy: 0.9963 - tf.math.sigmoid_7_accuracy: 0.9945 - val_loss: 0.8726 - val_tf.math.sigmoid_loss: 0.1778 - val_tf.math.sigmoid_1_loss: 0.0952 - val_tf.math.sigmoid_2_loss: 0.0830 - val_tf.math.sigmoid_3_loss: 0.0825 - val_tf.math.sigmoid_4_loss: 0.0844 - val_tf.math.sigmoid_5_loss: 0.0916 - val_tf.math.sigmoid_6_loss: 0.1082 - val_tf.math.sigmoid_7_loss: 0.1498 - val_tf.math.sigmoid_accuracy: 0.9933 - val_tf.math.sigmoid_1_accuracy: 0.9967 - val_tf.math.sigmoid_2_accuracy: 0.9969 - val_tf.math.sigmoid_3_accuracy: 0.9969 - val_tf.math.sigmoid_4_accuracy: 0.9969 - val_tf.math.sigmoid_5_accuracy: 0.9966 - val_tf.math.sigmoid_6_accuracy: 0.9960 - val_tf.math.sigmoid_7_accuracy: 0.9942
# Epoch 11/50
# 96/96 [==============================] - ETA: 0s - loss: 0.8300 - tf.math.sigmoid_loss: 0.1635 - tf.math.sigmoid_1_loss: 0.0885 - tf.math.sigmoid_2_loss: 0.0835 - tf.math.sigmoid_3_loss: 0.0825 - tf.math.sigmoid_4_loss: 0.0833 - tf.math.sigmoid_5_loss: 0.0864 - tf.math.sigmoid_6_loss: 0.0967 - tf.math.sigmoid_7_loss: 0.1457 - tf.math.sigmoid_accuracy: 0.9941 - tf.math.sigmoid_1_accuracy: 0.9968 - tf.math.sigmoid_2_accuracy: 0.9969 - tf.math.sigmoid_3_accuracy: 0.9969 - tf.math.sigmoid_4_accuracy: 0.9969 - tf.math.sigmoid_5_accuracy: 0.9968 - tf.math.sigmoid_6_accuracy: 0.9964 - tf.math.sigmoid_7_accuracy: 0.9946
# Epoch 11: val_loss did not improve from 0.87259
# 96/96 [==============================] - 31s 321ms/step - loss: 0.8300 - tf.math.sigmoid_loss: 0.1635 - tf.math.sigmoid_1_loss: 0.0885 - tf.math.sigmoid_2_loss: 0.0835 - tf.math.sigmoid_3_loss: 0.0825 - tf.math.sigmoid_4_loss: 0.0833 - tf.math.sigmoid_5_loss: 0.0864 - tf.math.sigmoid_6_loss: 0.0967 - tf.math.sigmoid_7_loss: 0.1457 - tf.math.sigmoid_accuracy: 0.9941 - tf.math.sigmoid_1_accuracy: 0.9968 - tf.math.sigmoid_2_accuracy: 0.9969 - tf.math.sigmoid_3_accuracy: 0.9969 - tf.math.sigmoid_4_accuracy: 0.9969 - tf.math.sigmoid_5_accuracy: 0.9968 - tf.math.sigmoid_6_accuracy: 0.9964 - tf.math.sigmoid_7_accuracy: 0.9946 - val_loss: 0.9158 - val_tf.math.sigmoid_loss: 0.1839 - val_tf.math.sigmoid_1_loss: 0.1066 - val_tf.math.sigmoid_2_loss: 0.0883 - val_tf.math.sigmoid_3_loss: 0.0867 - val_tf.math.sigmoid_4_loss: 0.0911 - val_tf.math.sigmoid_5_loss: 0.0960 - val_tf.math.sigmoid_6_loss: 0.1073 - val_tf.math.sigmoid_7_loss: 0.1560 - val_tf.math.sigmoid_accuracy: 0.9933 - val_tf.math.sigmoid_1_accuracy: 0.9963 - val_tf.math.sigmoid_2_accuracy: 0.9967 - val_tf.math.sigmoid_3_accuracy: 0.9968 - val_tf.math.sigmoid_4_accuracy: 0.9966 - val_tf.math.sigmoid_5_accuracy: 0.9964 - val_tf.math.sigmoid_6_accuracy: 0.9961 - val_tf.math.sigmoid_7_accuracy: 0.9942
# Epoch 12/50
# 96/96 [==============================] - ETA: 0s - loss: 0.7911 - tf.math.sigmoid_loss: 0.1403 - tf.math.sigmoid_1_loss: 0.0872 - tf.math.sigmoid_2_loss: 0.0822 - tf.math.sigmoid_3_loss: 0.0810 - tf.math.sigmoid_4_loss: 0.0816 - tf.math.sigmoid_5_loss: 0.0844 - tf.math.sigmoid_6_loss: 0.0938 - tf.math.sigmoid_7_loss: 0.1406 - tf.math.sigmoid_accuracy: 0.9950 - tf.math.sigmoid_1_accuracy: 0.9968 - tf.math.sigmoid_2_accuracy: 0.9969 - tf.math.sigmoid_3_accuracy: 0.9970 - tf.math.sigmoid_4_accuracy: 0.9970 - tf.math.sigmoid_5_accuracy: 0.9968 - tf.math.sigmoid_6_accuracy: 0.9965 - tf.math.sigmoid_7_accuracy: 0.9948
# Epoch 12: val_loss improved from 0.87259 to 0.85721, saving model to /content/drive/MyDrive/newstudy/mulimedia/LayerUNET-L5-F32-DSV.h5
# 96/96 [==============================] - 32s 336ms/step - loss: 0.7911 - tf.math.sigmoid_loss: 0.1403 - tf.math.sigmoid_1_loss: 0.0872 - tf.math.sigmoid_2_loss: 0.0822 - tf.math.sigmoid_3_loss: 0.0810 - tf.math.sigmoid_4_loss: 0.0816 - tf.math.sigmoid_5_loss: 0.0844 - tf.math.sigmoid_6_loss: 0.0938 - tf.math.sigmoid_7_loss: 0.1406 - tf.math.sigmoid_accuracy: 0.9950 - tf.math.sigmoid_1_accuracy: 0.9968 - tf.math.sigmoid_2_accuracy: 0.9969 - tf.math.sigmoid_3_accuracy: 0.9970 - tf.math.sigmoid_4_accuracy: 0.9970 - tf.math.sigmoid_5_accuracy: 0.9968 - tf.math.sigmoid_6_accuracy: 0.9965 - tf.math.sigmoid_7_accuracy: 0.9948 - val_loss: 0.8572 - val_tf.math.sigmoid_loss: 0.1752 - val_tf.math.sigmoid_1_loss: 0.0893 - val_tf.math.sigmoid_2_loss: 0.0850 - val_tf.math.sigmoid_3_loss: 0.0843 - val_tf.math.sigmoid_4_loss: 0.0860 - val_tf.math.sigmoid_5_loss: 0.0925 - val_tf.math.sigmoid_6_loss: 0.1007 - val_tf.math.sigmoid_7_loss: 0.1441 - val_tf.math.sigmoid_accuracy: 0.9934 - val_tf.math.sigmoid_1_accuracy: 0.9967 - val_tf.math.sigmoid_2_accuracy: 0.9968 - val_tf.math.sigmoid_3_accuracy: 0.9968 - val_tf.math.sigmoid_4_accuracy: 0.9968 - val_tf.math.sigmoid_5_accuracy: 0.9965 - val_tf.math.sigmoid_6_accuracy: 0.9962 - val_tf.math.sigmoid_7_accuracy: 0.9946
# Epoch 13/50
# 96/96 [==============================] - ETA: 0s - loss: 0.7714 - tf.math.sigmoid_loss: 0.1323 - tf.math.sigmoid_1_loss: 0.0850 - tf.math.sigmoid_2_loss: 0.0806 - tf.math.sigmoid_3_loss: 0.0795 - tf.math.sigmoid_4_loss: 0.0805 - tf.math.sigmoid_5_loss: 0.0831 - tf.math.sigmoid_6_loss: 0.0919 - tf.math.sigmoid_7_loss: 0.1384 - tf.math.sigmoid_accuracy: 0.9953 - tf.math.sigmoid_1_accuracy: 0.9969 - tf.math.sigmoid_2_accuracy: 0.9970 - tf.math.sigmoid_3_accuracy: 0.9970 - tf.math.sigmoid_4_accuracy: 0.9970 - tf.math.sigmoid_5_accuracy: 0.9969 - tf.math.sigmoid_6_accuracy: 0.9966 - tf.math.sigmoid_7_accuracy: 0.9949
# Epoch 13: val_loss improved from 0.85721 to 0.80794, saving model to /content/drive/MyDrive/newstudy/mulimedia/LayerUNET-L5-F32-DSV.h5
# 96/96 [==============================] - 32s 336ms/step - loss: 0.7714 - tf.math.sigmoid_loss: 0.1323 - tf.math.sigmoid_1_loss: 0.0850 - tf.math.sigmoid_2_loss: 0.0806 - tf.math.sigmoid_3_loss: 0.0795 - tf.math.sigmoid_4_loss: 0.0805 - tf.math.sigmoid_5_loss: 0.0831 - tf.math.sigmoid_6_loss: 0.0919 - tf.math.sigmoid_7_loss: 0.1384 - tf.math.sigmoid_accuracy: 0.9953 - tf.math.sigmoid_1_accuracy: 0.9969 - tf.math.sigmoid_2_accuracy: 0.9970 - tf.math.sigmoid_3_accuracy: 0.9970 - tf.math.sigmoid_4_accuracy: 0.9970 - tf.math.sigmoid_5_accuracy: 0.9969 - tf.math.sigmoid_6_accuracy: 0.9966 - tf.math.sigmoid_7_accuracy: 0.9949 - val_loss: 0.8079 - val_tf.math.sigmoid_loss: 0.1428 - val_tf.math.sigmoid_1_loss: 0.0921 - val_tf.math.sigmoid_2_loss: 0.0825 - val_tf.math.sigmoid_3_loss: 0.0808 - val_tf.math.sigmoid_4_loss: 0.0838 - val_tf.math.sigmoid_5_loss: 0.0857 - val_tf.math.sigmoid_6_loss: 0.0959 - val_tf.math.sigmoid_7_loss: 0.1442 - val_tf.math.sigmoid_accuracy: 0.9949 - val_tf.math.sigmoid_1_accuracy: 0.9966 - val_tf.math.sigmoid_2_accuracy: 0.9969 - val_tf.math.sigmoid_3_accuracy: 0.9969 - val_tf.math.sigmoid_4_accuracy: 0.9969 - val_tf.math.sigmoid_5_accuracy: 0.9968 - val_tf.math.sigmoid_6_accuracy: 0.9964 - val_tf.math.sigmoid_7_accuracy: 0.9944
# Epoch 14/50
# 96/96 [==============================] - ETA: 0s - loss: 1.0426 - tf.math.sigmoid_loss: 0.2234 - tf.math.sigmoid_1_loss: 0.1374 - tf.math.sigmoid_2_loss: 0.1044 - tf.math.sigmoid_3_loss: 0.0955 - tf.math.sigmoid_4_loss: 0.0943 - tf.math.sigmoid_5_loss: 0.0995 - tf.math.sigmoid_6_loss: 0.1119 - tf.math.sigmoid_7_loss: 0.1762 - tf.math.sigmoid_accuracy: 0.9912 - tf.math.sigmoid_1_accuracy: 0.9945 - tf.math.sigmoid_2_accuracy: 0.9961 - tf.math.sigmoid_3_accuracy: 0.9964 - tf.math.sigmoid_4_accuracy: 0.9965 - tf.math.sigmoid_5_accuracy: 0.9963 - tf.math.sigmoid_6_accuracy: 0.9958 - tf.math.sigmoid_7_accuracy: 0.9933
# Epoch 14: val_loss did not improve from 0.80794
# 96/96 [==============================] - 31s 320ms/step - loss: 1.0426 - tf.math.sigmoid_loss: 0.2234 - tf.math.sigmoid_1_loss: 0.1374 - tf.math.sigmoid_2_loss: 0.1044 - tf.math.sigmoid_3_loss: 0.0955 - tf.math.sigmoid_4_loss: 0.0943 - tf.math.sigmoid_5_loss: 0.0995 - tf.math.sigmoid_6_loss: 0.1119 - tf.math.sigmoid_7_loss: 0.1762 - tf.math.sigmoid_accuracy: 0.9912 - tf.math.sigmoid_1_accuracy: 0.9945 - tf.math.sigmoid_2_accuracy: 0.9961 - tf.math.sigmoid_3_accuracy: 0.9964 - tf.math.sigmoid_4_accuracy: 0.9965 - tf.math.sigmoid_5_accuracy: 0.9963 - tf.math.sigmoid_6_accuracy: 0.9958 - tf.math.sigmoid_7_accuracy: 0.9933 - val_loss: 6.7125 - val_tf.math.sigmoid_loss: 0.3904 - val_tf.math.sigmoid_1_loss: 4.2144 - val_tf.math.sigmoid_2_loss: 0.4517 - val_tf.math.sigmoid_3_loss: 0.3820 - val_tf.math.sigmoid_4_loss: 0.1811 - val_tf.math.sigmoid_5_loss: 0.6283 - val_tf.math.sigmoid_6_loss: 0.1826 - val_tf.math.sigmoid_7_loss: 0.2822 - val_tf.math.sigmoid_accuracy: 0.9854 - val_tf.math.sigmoid_1_accuracy: 0.5370 - val_tf.math.sigmoid_2_accuracy: 0.9770 - val_tf.math.sigmoid_3_accuracy: 0.9848 - val_tf.math.sigmoid_4_accuracy: 0.9930 - val_tf.math.sigmoid_5_accuracy: 0.9546 - val_tf.math.sigmoid_6_accuracy: 0.9929 - val_tf.math.sigmoid_7_accuracy: 0.9898
# Epoch 15/50
# 96/96 [==============================] - ETA: 0s - loss: 0.9282 - tf.math.sigmoid_loss: 0.1900 - tf.math.sigmoid_1_loss: 0.1089 - tf.math.sigmoid_2_loss: 0.0945 - tf.math.sigmoid_3_loss: 0.0904 - tf.math.sigmoid_4_loss: 0.0910 - tf.math.sigmoid_5_loss: 0.0931 - tf.math.sigmoid_6_loss: 0.1037 - tf.math.sigmoid_7_loss: 0.1565 - tf.math.sigmoid_accuracy: 0.9930 - tf.math.sigmoid_1_accuracy: 0.9960 - tf.math.sigmoid_2_accuracy: 0.9964 - tf.math.sigmoid_3_accuracy: 0.9966 - tf.math.sigmoid_4_accuracy: 0.9966 - tf.math.sigmoid_5_accuracy: 0.9965 - tf.math.sigmoid_6_accuracy: 0.9961 - tf.math.sigmoid_7_accuracy: 0.9942
# Epoch 15: val_loss did not improve from 0.80794
# 96/96 [==============================] - 31s 320ms/step - loss: 0.9282 - tf.math.sigmoid_loss: 0.1900 - tf.math.sigmoid_1_loss: 0.1089 - tf.math.sigmoid_2_loss: 0.0945 - tf.math.sigmoid_3_loss: 0.0904 - tf.math.sigmoid_4_loss: 0.0910 - tf.math.sigmoid_5_loss: 0.0931 - tf.math.sigmoid_6_loss: 0.1037 - tf.math.sigmoid_7_loss: 0.1565 - tf.math.sigmoid_accuracy: 0.9930 - tf.math.sigmoid_1_accuracy: 0.9960 - tf.math.sigmoid_2_accuracy: 0.9964 - tf.math.sigmoid_3_accuracy: 0.9966 - tf.math.sigmoid_4_accuracy: 0.9966 - tf.math.sigmoid_5_accuracy: 0.9965 - tf.math.sigmoid_6_accuracy: 0.9961 - tf.math.sigmoid_7_accuracy: 0.9942 - val_loss: 0.8708 - val_tf.math.sigmoid_loss: 0.1667 - val_tf.math.sigmoid_1_loss: 0.0977 - val_tf.math.sigmoid_2_loss: 0.0856 - val_tf.math.sigmoid_3_loss: 0.0872 - val_tf.math.sigmoid_4_loss: 0.0894 - val_tf.math.sigmoid_5_loss: 0.0939 - val_tf.math.sigmoid_6_loss: 0.1028 - val_tf.math.sigmoid_7_loss: 0.1475 - val_tf.math.sigmoid_accuracy: 0.9938 - val_tf.math.sigmoid_1_accuracy: 0.9964 - val_tf.math.sigmoid_2_accuracy: 0.9968 - val_tf.math.sigmoid_3_accuracy: 0.9967 - val_tf.math.sigmoid_4_accuracy: 0.9966 - val_tf.math.sigmoid_5_accuracy: 0.9964 - val_tf.math.sigmoid_6_accuracy: 0.9961 - val_tf.math.sigmoid_7_accuracy: 0.9945
# Epoch 16/50
# 96/96 [==============================] - ETA: 0s - loss: 0.7821 - tf.math.sigmoid_loss: 0.1414 - tf.math.sigmoid_1_loss: 0.0880 - tf.math.sigmoid_2_loss: 0.0816 - tf.math.sigmoid_3_loss: 0.0800 - tf.math.sigmoid_4_loss: 0.0810 - tf.math.sigmoid_5_loss: 0.0833 - tf.math.sigmoid_6_loss: 0.0915 - tf.math.sigmoid_7_loss: 0.1352 - tf.math.sigmoid_accuracy: 0.9949 - tf.math.sigmoid_1_accuracy: 0.9968 - tf.math.sigmoid_2_accuracy: 0.9970 - tf.math.sigmoid_3_accuracy: 0.9970 - tf.math.sigmoid_4_accuracy: 0.9970 - tf.math.sigmoid_5_accuracy: 0.9969 - tf.math.sigmoid_6_accuracy: 0.9966 - tf.math.sigmoid_7_accuracy: 0.9950
# Epoch 16: val_loss did not improve from 0.80794
# 96/96 [==============================] - 31s 324ms/step - loss: 0.7821 - tf.math.sigmoid_loss: 0.1414 - tf.math.sigmoid_1_loss: 0.0880 - tf.math.sigmoid_2_loss: 0.0816 - tf.math.sigmoid_3_loss: 0.0800 - tf.math.sigmoid_4_loss: 0.0810 - tf.math.sigmoid_5_loss: 0.0833 - tf.math.sigmoid_6_loss: 0.0915 - tf.math.sigmoid_7_loss: 0.1352 - tf.math.sigmoid_accuracy: 0.9949 - tf.math.sigmoid_1_accuracy: 0.9968 - tf.math.sigmoid_2_accuracy: 0.9970 - tf.math.sigmoid_3_accuracy: 0.9970 - tf.math.sigmoid_4_accuracy: 0.9970 - tf.math.sigmoid_5_accuracy: 0.9969 - tf.math.sigmoid_6_accuracy: 0.9966 - tf.math.sigmoid_7_accuracy: 0.9950 - val_loss: 0.8812 - val_tf.math.sigmoid_loss: 0.1788 - val_tf.math.sigmoid_1_loss: 0.1103 - val_tf.math.sigmoid_2_loss: 0.0890 - val_tf.math.sigmoid_3_loss: 0.0853 - val_tf.math.sigmoid_4_loss: 0.0874 - val_tf.math.sigmoid_5_loss: 0.0909 - val_tf.math.sigmoid_6_loss: 0.0994 - val_tf.math.sigmoid_7_loss: 0.1402 - val_tf.math.sigmoid_accuracy: 0.9935 - val_tf.math.sigmoid_1_accuracy: 0.9959 - val_tf.math.sigmoid_2_accuracy: 0.9967 - val_tf.math.sigmoid_3_accuracy: 0.9968 - val_tf.math.sigmoid_4_accuracy: 0.9967 - val_tf.math.sigmoid_5_accuracy: 0.9966 - val_tf.math.sigmoid_6_accuracy: 0.9963 - val_tf.math.sigmoid_7_accuracy: 0.9947
# Epoch 17/50
# 96/96 [==============================] - ETA: 0s - loss: 0.7582 - tf.math.sigmoid_loss: 0.1377 - tf.math.sigmoid_1_loss: 0.0851 - tf.math.sigmoid_2_loss: 0.0792 - tf.math.sigmoid_3_loss: 0.0771 - tf.math.sigmoid_4_loss: 0.0779 - tf.math.sigmoid_5_loss: 0.0803 - tf.math.sigmoid_6_loss: 0.0886 - tf.math.sigmoid_7_loss: 0.1324 - tf.math.sigmoid_accuracy: 0.9951 - tf.math.sigmoid_1_accuracy: 0.9969 - tf.math.sigmoid_2_accuracy: 0.9971 - tf.math.sigmoid_3_accuracy: 0.9971 - tf.math.sigmoid_4_accuracy: 0.9971 - tf.math.sigmoid_5_accuracy: 0.9970 - tf.math.sigmoid_6_accuracy: 0.9967 - tf.math.sigmoid_7_accuracy: 0.9951
# Epoch 17: val_loss improved from 0.80794 to 0.79375, saving model to /content/drive/MyDrive/newstudy/mulimedia/LayerUNET-L5-F32-DSV.h5
# 96/96 [==============================] - 32s 336ms/step - loss: 0.7582 - tf.math.sigmoid_loss: 0.1377 - tf.math.sigmoid_1_loss: 0.0851 - tf.math.sigmoid_2_loss: 0.0792 - tf.math.sigmoid_3_loss: 0.0771 - tf.math.sigmoid_4_loss: 0.0779 - tf.math.sigmoid_5_loss: 0.0803 - tf.math.sigmoid_6_loss: 0.0886 - tf.math.sigmoid_7_loss: 0.1324 - tf.math.sigmoid_accuracy: 0.9951 - tf.math.sigmoid_1_accuracy: 0.9969 - tf.math.sigmoid_2_accuracy: 0.9971 - tf.math.sigmoid_3_accuracy: 0.9971 - tf.math.sigmoid_4_accuracy: 0.9971 - tf.math.sigmoid_5_accuracy: 0.9970 - tf.math.sigmoid_6_accuracy: 0.9967 - tf.math.sigmoid_7_accuracy: 0.9951 - val_loss: 0.7938 - val_tf.math.sigmoid_loss: 0.1312 - val_tf.math.sigmoid_1_loss: 0.0931 - val_tf.math.sigmoid_2_loss: 0.0838 - val_tf.math.sigmoid_3_loss: 0.0818 - val_tf.math.sigmoid_4_loss: 0.0833 - val_tf.math.sigmoid_5_loss: 0.0863 - val_tf.math.sigmoid_6_loss: 0.0970 - val_tf.math.sigmoid_7_loss: 0.1372 - val_tf.math.sigmoid_accuracy: 0.9954 - val_tf.math.sigmoid_1_accuracy: 0.9966 - val_tf.math.sigmoid_2_accuracy: 0.9969 - val_tf.math.sigmoid_3_accuracy: 0.9969 - val_tf.math.sigmoid_4_accuracy: 0.9969 - val_tf.math.sigmoid_5_accuracy: 0.9967 - val_tf.math.sigmoid_6_accuracy: 0.9963 - val_tf.math.sigmoid_7_accuracy: 0.9949
# Epoch 18/50
# 96/96 [==============================] - ETA: 0s - loss: 0.7293 - tf.math.sigmoid_loss: 0.1207 - tf.math.sigmoid_1_loss: 0.0833 - tf.math.sigmoid_2_loss: 0.0783 - tf.math.sigmoid_3_loss: 0.0758 - tf.math.sigmoid_4_loss: 0.0767 - tf.math.sigmoid_5_loss: 0.0788 - tf.math.sigmoid_6_loss: 0.0864 - tf.math.sigmoid_7_loss: 0.1294 - tf.math.sigmoid_accuracy: 0.9957 - tf.math.sigmoid_1_accuracy: 0.9969 - tf.math.sigmoid_2_accuracy: 0.9971 - tf.math.sigmoid_3_accuracy: 0.9972 - tf.math.sigmoid_4_accuracy: 0.9972 - tf.math.sigmoid_5_accuracy: 0.9971 - tf.math.sigmoid_6_accuracy: 0.9968 - tf.math.sigmoid_7_accuracy: 0.9953
# Epoch 18: val_loss improved from 0.79375 to 0.76948, saving model to /content/drive/MyDrive/newstudy/mulimedia/LayerUNET-L5-F32-DSV.h5
# 96/96 [==============================] - 33s 341ms/step - loss: 0.7293 - tf.math.sigmoid_loss: 0.1207 - tf.math.sigmoid_1_loss: 0.0833 - tf.math.sigmoid_2_loss: 0.0783 - tf.math.sigmoid_3_loss: 0.0758 - tf.math.sigmoid_4_loss: 0.0767 - tf.math.sigmoid_5_loss: 0.0788 - tf.math.sigmoid_6_loss: 0.0864 - tf.math.sigmoid_7_loss: 0.1294 - tf.math.sigmoid_accuracy: 0.9957 - tf.math.sigmoid_1_accuracy: 0.9969 - tf.math.sigmoid_2_accuracy: 0.9971 - tf.math.sigmoid_3_accuracy: 0.9972 - tf.math.sigmoid_4_accuracy: 0.9972 - tf.math.sigmoid_5_accuracy: 0.9971 - tf.math.sigmoid_6_accuracy: 0.9968 - tf.math.sigmoid_7_accuracy: 0.9953 - val_loss: 0.7695 - val_tf.math.sigmoid_loss: 0.1265 - val_tf.math.sigmoid_1_loss: 0.0839 - val_tf.math.sigmoid_2_loss: 0.0806 - val_tf.math.sigmoid_3_loss: 0.0800 - val_tf.math.sigmoid_4_loss: 0.0813 - val_tf.math.sigmoid_5_loss: 0.0836 - val_tf.math.sigmoid_6_loss: 0.0943 - val_tf.math.sigmoid_7_loss: 0.1393 - val_tf.math.sigmoid_accuracy: 0.9953 - val_tf.math.sigmoid_1_accuracy: 0.9969 - val_tf.math.sigmoid_2_accuracy: 0.9970 - val_tf.math.sigmoid_3_accuracy: 0.9970 - val_tf.math.sigmoid_4_accuracy: 0.9969 - val_tf.math.sigmoid_5_accuracy: 0.9969 - val_tf.math.sigmoid_6_accuracy: 0.9965 - val_tf.math.sigmoid_7_accuracy: 0.9948
# Epoch 19/50
# 96/96 [==============================] - ETA: 0s - loss: 0.7281 - tf.math.sigmoid_loss: 0.1186 - tf.math.sigmoid_1_loss: 0.0824 - tf.math.sigmoid_2_loss: 0.0776 - tf.math.sigmoid_3_loss: 0.0759 - tf.math.sigmoid_4_loss: 0.0769 - tf.math.sigmoid_5_loss: 0.0791 - tf.math.sigmoid_6_loss: 0.0867 - tf.math.sigmoid_7_loss: 0.1309 - tf.math.sigmoid_accuracy: 0.9958 - tf.math.sigmoid_1_accuracy: 0.9970 - tf.math.sigmoid_2_accuracy: 0.9971 - tf.math.sigmoid_3_accuracy: 0.9972 - tf.math.sigmoid_4_accuracy: 0.9972 - tf.math.sigmoid_5_accuracy: 0.9971 - tf.math.sigmoid_6_accuracy: 0.9968 - tf.math.sigmoid_7_accuracy: 0.9952
# Epoch 19: val_loss improved from 0.76948 to 0.76027, saving model to /content/drive/MyDrive/newstudy/mulimedia/LayerUNET-L5-F32-DSV.h5
# 96/96 [==============================] - 32s 337ms/step - loss: 0.7281 - tf.math.sigmoid_loss: 0.1186 - tf.math.sigmoid_1_loss: 0.0824 - tf.math.sigmoid_2_loss: 0.0776 - tf.math.sigmoid_3_loss: 0.0759 - tf.math.sigmoid_4_loss: 0.0769 - tf.math.sigmoid_5_loss: 0.0791 - tf.math.sigmoid_6_loss: 0.0867 - tf.math.sigmoid_7_loss: 0.1309 - tf.math.sigmoid_accuracy: 0.9958 - tf.math.sigmoid_1_accuracy: 0.9970 - tf.math.sigmoid_2_accuracy: 0.9971 - tf.math.sigmoid_3_accuracy: 0.9972 - tf.math.sigmoid_4_accuracy: 0.9972 - tf.math.sigmoid_5_accuracy: 0.9971 - tf.math.sigmoid_6_accuracy: 0.9968 - tf.math.sigmoid_7_accuracy: 0.9952 - val_loss: 0.7603 - val_tf.math.sigmoid_loss: 0.1232 - val_tf.math.sigmoid_1_loss: 0.0839 - val_tf.math.sigmoid_2_loss: 0.0797 - val_tf.math.sigmoid_3_loss: 0.0784 - val_tf.math.sigmoid_4_loss: 0.0797 - val_tf.math.sigmoid_5_loss: 0.0845 - val_tf.math.sigmoid_6_loss: 0.0953 - val_tf.math.sigmoid_7_loss: 0.1355 - val_tf.math.sigmoid_accuracy: 0.9956 - val_tf.math.sigmoid_1_accuracy: 0.9969 - val_tf.math.sigmoid_2_accuracy: 0.9970 - val_tf.math.sigmoid_3_accuracy: 0.9970 - val_tf.math.sigmoid_4_accuracy: 0.9970 - val_tf.math.sigmoid_5_accuracy: 0.9968 - val_tf.math.sigmoid_6_accuracy: 0.9964 - val_tf.math.sigmoid_7_accuracy: 0.9949
# Epoch 20/50
# 30/96 [========>.....................] - ETA: 19s - loss: 0.6892 - tf.math.sigmoid_loss: 0.1162 - tf.math.sigmoid_1_loss: 0.0789 - tf.math.sigmoid_2_loss: 0.0737 - tf.math.sigmoid_3_loss: 0.0713 - tf.math.sigmoid_4_loss: 0.0723 - tf.math.sigmoid_5_loss: 0.0739 - tf.math.sigmoid_6_loss: 0.0809 - tf.math.sigmoid_7_loss: 0.1220 - tf.math.sigmoid_accuracy: 0.9960 - tf.math.sigmoid_1_accuracy: 0.9972 - tf.math.sigmoid_2_accuracy: 0.9974 - tf.math.sigmoid_3_accuracy: 0.9974 - tf.math.sigmoid_4_accuracy: 0.9974 - tf.math.sigmoid_5_accuracy: 0.9974 - tf.math.sigmoid_6_accuracy: 0.9971 - tf.math.sigmoid_7_accuracy: 0.9957

# %%
save_dir = f'/content/drive/MyDrive/newstudy/mulimedia/model'

if os.path.exists(save_dir) == False:
  os.makedirs(save_dir)

new_model_num = 1
while (os.path.exists(f'{save_dir}/Model{new_model_num}.h5')):
  new_model_num += 1

model.save(f'{save_dir}/Model{new_model_num}.h5')
if os.path.exists(cp_dir):
  shutil.move(cp_dir,f'{save_dir}/Best{new_model_num}.h5')
print(f'{save_dir}에 {new_model_num}번째 모델이 저장 되었습니다.')
display_history(history.history,save_dir,new_model_num,True,True,True)

# %%
display_dataset(train_dataset,True)
# Out:
# 1/1 [==============================] - 0s 37ms/step

# %%
test_x = glob.glob('/content/drive/MyDrive/newstudy/mulimedia/originalimg/*.png')
display_test(test_x,len(test_x))

# %% [markdown]
# 모델 불러오기
# =========================

# %%
# 이전에 컴파일 한 모델 불러오기
load_dir = '/content/drive/MyDrive/newstudy/mulimedia/model/'
model_num = 50

sel_best = True
model_name = ''

if sel_best == True: 
  model_name = 'Best' 
else :
  model_name = 'Model'

#model = tf.keras.models.load_model(f'/content/drive/MyDrive/data/layerUNET-C1-L5-F32-VER2-DSV.h5',custom_objects= custom_loss)
model = tf.keras.models.load_model(f'{load_dir}/{model_name}{model_num}.h5',custom_objects= custom_loss)
history = pd.read_csv(f'{load_dir}/History{model_num}.csv')
display_history(history,load_dir,model_num,True,False,True)

# %%
from google.colab import drive
drive.mount('/content/drive')
